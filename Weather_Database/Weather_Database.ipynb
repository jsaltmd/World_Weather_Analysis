# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=67f5ffdc9f3b9208f2d054e49f2d721d

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khandyga
# Processing Record 2 of Set 1 | derzhavinsk
# Processing Record 3 of Set 1 | bangassou
# Processing Record 4 of Set 1 | methoni
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | miandrivazo
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | port hedland
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | kaitangata
# Processing Record 14 of Set 1 | hirara
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | chicama
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | guadalajara
# Processing Record 20 of Set 1 | strezhevoy
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | akureyri
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | podyuga
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | mangrol
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | inuvik
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | inhambane
# Processing Record 32 of Set 1 | uvinza
# Processing Record 33 of Set 1 | luderitz
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | lavrentiya
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | jinxiang
# Processing Record 45 of Set 1 | sidi ali
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | nyrob
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | den helder
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | saint-augustin
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | necochea
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | rio gallegos
# Processing Record 12 of Set 2 | quthing
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | ahipara
# Processing Record 15 of Set 2 | moses lake
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | daimiel
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | kahului
# Processing Record 22 of Set 2 | huixtla
# Processing Record 23 of Set 2 | norsup
# Processing Record 24 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | esperance
# Processing Record 31 of Set 2 | okato
# Processing Record 32 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | baloda
# Processing Record 35 of Set 2 | gigmoto
# Processing Record 36 of Set 2 | ajdabiya
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | vestmannaeyjar
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | posse
# Processing Record 42 of Set 2 | progreso
# Processing Record 43 of Set 2 | itupiranga
# Processing Record 44 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 2 | port moresby
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | rio grande
# Processing Record 50 of Set 2 | chapleau
# Processing Record 1 of Set 3 | ayan
# Processing Record 2 of Set 3 | merauke
# Processing Record 3 of Set 3 | champasak
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | carutapera
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | lewisporte
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | chiredzi
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | pamplona
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | jumla
# Processing Record 15 of Set 3 | bitung
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | axim
# Processing Record 18 of Set 3 | mangai
# Processing Record 19 of Set 3 | sinnamary
# Processing Record 20 of Set 3 | tibiri
# Processing Record 21 of Set 3 | lorengau
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | baruun-urt
# Processing Record 24 of Set 3 | sola
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | kulhudhuffushi
# Processing Record 27 of Set 3 | daru
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | vavoua
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | sigli
# Processing Record 33 of Set 3 | iquique
# Processing Record 34 of Set 3 | richards bay
# Processing Record 35 of Set 3 | yoichi
# Processing Record 36 of Set 3 | avarua
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | ishigaki
# Processing Record 39 of Set 3 | barahona
# Processing Record 40 of Set 3 | taoudenni
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | hualmay
# Processing Record 43 of Set 3 | hermanus
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | marshall
# Processing Record 46 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 3 | matagami
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | port-gentil
# Processing Record 50 of Set 3 | banjar
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | coquimbo
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | tokur
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | leua
# Processing Record 7 of Set 4 | elko
# Processing Record 8 of Set 4 | custoias
# Processing Record 9 of Set 4 | ipeti
# City not found. Skipping...
# Processing Record 10 of Set 4 | kamenka
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | pingzhuang
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | ituporanga
# Processing Record 16 of Set 4 | cap-haitien
# Processing Record 17 of Set 4 | margate
# Processing Record 18 of Set 4 | semme
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | vilyuysk
# Processing Record 21 of Set 4 | khor
# Processing Record 22 of Set 4 | ballina
# Processing Record 23 of Set 4 | marica
# Processing Record 24 of Set 4 | zhigansk
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | havre-saint-pierre
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | katobu
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | douglas
# Processing Record 31 of Set 4 | sao filipe
# Processing Record 32 of Set 4 | srednekolymsk
# Processing Record 33 of Set 4 | peniche
# Processing Record 34 of Set 4 | toora-khem
# Processing Record 35 of Set 4 | lakes entrance
# Processing Record 36 of Set 4 | san vicente
# Processing Record 37 of Set 4 | tha chang
# Processing Record 38 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 4 | hobart
# Processing Record 42 of Set 4 | pangai
# Processing Record 43 of Set 4 | te anau
# Processing Record 44 of Set 4 | mayachnyy
# Processing Record 45 of Set 4 | sucre
# Processing Record 46 of Set 4 | puerto lopez
# Processing Record 47 of Set 4 | belyy yar
# Processing Record 48 of Set 4 | vaini
# Processing Record 49 of Set 4 | rapid city
# Processing Record 50 of Set 4 | shelburne
# Processing Record 1 of Set 5 | aba
# Processing Record 2 of Set 5 | aykhal
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | caucaia
# Processing Record 5 of Set 5 | catamarca
# Processing Record 6 of Set 5 | high level
# Processing Record 7 of Set 5 | beidao
# Processing Record 8 of Set 5 | lardos
# Processing Record 9 of Set 5 | tabas
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | kabinda
# Processing Record 13 of Set 5 | prince rupert
# Processing Record 14 of Set 5 | clinton
# Processing Record 15 of Set 5 | aras
# Processing Record 16 of Set 5 | jasper
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | kismayo
# Processing Record 19 of Set 5 | port stanley
# Processing Record 20 of Set 5 | airai
# Processing Record 21 of Set 5 | kenora
# Processing Record 22 of Set 5 | gat
# Processing Record 23 of Set 5 | saint anthony
# Processing Record 24 of Set 5 | ferrol
# Processing Record 25 of Set 5 | dodge city
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | barcelos
# Processing Record 28 of Set 5 | hervey bay
# Processing Record 29 of Set 5 | ucluelet
# Processing Record 30 of Set 5 | suhbaatar
# Processing Record 31 of Set 5 | virginia beach
# Processing Record 32 of Set 5 | amurzet
# Processing Record 33 of Set 5 | that phanom
# Processing Record 34 of Set 5 | otane
# Processing Record 35 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 5 | tolaga bay
# Processing Record 37 of Set 5 | bay roberts
# Processing Record 38 of Set 5 | cusuna
# Processing Record 39 of Set 5 | oktyabrskiy
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | puerto carreno
# Processing Record 42 of Set 5 | abiy adi
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint-joseph
# Processing Record 44 of Set 5 | port-cartier
# Processing Record 45 of Set 5 | udachnyy
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | pontianak
# Processing Record 49 of Set 5 | sar-e pul
# Processing Record 50 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 6 | hovd
# Processing Record 2 of Set 6 | camacha
# Processing Record 3 of Set 6 | siverek
# Processing Record 4 of Set 6 | miandoab
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | corinto
# Processing Record 8 of Set 6 | sampit
# Processing Record 9 of Set 6 | chara
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | tasiilaq
# Processing Record 12 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 13 of Set 6 | la orilla
# Processing Record 14 of Set 6 | dicabisagan
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | lesnoy
# Processing Record 17 of Set 6 | qaanaaq
# Processing Record 18 of Set 6 | sakaiminato
# Processing Record 19 of Set 6 | hambantota
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | cayenne
# Processing Record 22 of Set 6 | kattivakkam
# Processing Record 23 of Set 6 | riacho de santana
# Processing Record 24 of Set 6 | kaeo
# Processing Record 25 of Set 6 | egersund
# Processing Record 26 of Set 6 | nijar
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | waipawa
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | north platte
# Processing Record 32 of Set 6 | ginda
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | xining
# Processing Record 35 of Set 6 | touros
# Processing Record 36 of Set 6 | atar
# Processing Record 37 of Set 6 | sabang
# Processing Record 38 of Set 6 | sao paulo de olivenca
# Processing Record 39 of Set 6 | dikson
# Processing Record 40 of Set 6 | marion
# Processing Record 41 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 6 | bagdarin
# Processing Record 43 of Set 6 | raudeberg
# Processing Record 44 of Set 6 | port hawkesbury
# Processing Record 45 of Set 6 | jalu
# Processing Record 46 of Set 6 | preston
# Processing Record 47 of Set 6 | sembakung
# Processing Record 48 of Set 6 | ternate
# Processing Record 49 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 6 | aiquile
# Processing Record 1 of Set 7 | arraial do cabo
# Processing Record 2 of Set 7 | kirakira
# Processing Record 3 of Set 7 | randolph
# Processing Record 4 of Set 7 | joshimath
# Processing Record 5 of Set 7 | teno
# Processing Record 6 of Set 7 | yuci
# Processing Record 7 of Set 7 | seymchan
# Processing Record 8 of Set 7 | yichun
# Processing Record 9 of Set 7 | sao felix do xingu
# Processing Record 10 of Set 7 | eureka
# Processing Record 11 of Set 7 | probolinggo
# Processing Record 12 of Set 7 | nelson bay
# Processing Record 13 of Set 7 | itoman
# Processing Record 14 of Set 7 | egvekinot
# Processing Record 15 of Set 7 | iquitos
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | prado
# Processing Record 18 of Set 7 | hwange
# Processing Record 19 of Set 7 | shakhtinsk
# Processing Record 20 of Set 7 | san-pedro
# Processing Record 21 of Set 7 | zwedru
# Processing Record 22 of Set 7 | taksimo
# Processing Record 23 of Set 7 | harper
# Processing Record 24 of Set 7 | noyon
# Processing Record 25 of Set 7 | bilma
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | alekseyevsk
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | seoul
# Processing Record 30 of Set 7 | biloela
# Processing Record 31 of Set 7 | ponta do sol
# Processing Record 32 of Set 7 | jiexiu
# Processing Record 33 of Set 7 | golden
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | qaqortoq
# Processing Record 36 of Set 7 | faanui
# Processing Record 37 of Set 7 | talnakh
# Processing Record 38 of Set 7 | bonneville
# Processing Record 39 of Set 7 | camana
# Processing Record 40 of Set 7 | spitsevka
# Processing Record 41 of Set 7 | marsh harbour
# Processing Record 42 of Set 7 | tadine
# Processing Record 43 of Set 7 | stepnogorsk
# Processing Record 44 of Set 7 | ravar
# Processing Record 45 of Set 7 | itarema
# Processing Record 46 of Set 7 | bontang
# Processing Record 47 of Set 7 | nova venecia
# Processing Record 48 of Set 7 | rosarito
# Processing Record 49 of Set 7 | duz
# City not found. Skipping...
# Processing Record 50 of Set 7 | nizhniy mamon
# Processing Record 1 of Set 8 | klaksvik
# Processing Record 2 of Set 8 | charters towers
# Processing Record 3 of Set 8 | kwinana
# Processing Record 4 of Set 8 | kaniama
# Processing Record 5 of Set 8 | manzhouli
# Processing Record 6 of Set 8 | sangar
# Processing Record 7 of Set 8 | puerto leguizamo
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 8 | tonekabon
# Processing Record 10 of Set 8 | noumea
# Processing Record 11 of Set 8 | artyom
# Processing Record 12 of Set 8 | shadegan
# Processing Record 13 of Set 8 | plettenberg bay
# Processing Record 14 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 8 | luganville
# Processing Record 16 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 8 | altay
# Processing Record 19 of Set 8 | arman
# Processing Record 20 of Set 8 | waounde
# Processing Record 21 of Set 8 | butterworth
# Processing Record 22 of Set 8 | tautira
# Processing Record 23 of Set 8 | saint-pierre
# Processing Record 24 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 8 | marzuq
# Processing Record 26 of Set 8 | gimli
# Processing Record 27 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 8 | konevo
# Processing Record 29 of Set 8 | bose
# Processing Record 30 of Set 8 | atambua
# Processing Record 31 of Set 8 | wanning
# Processing Record 32 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 8 | verkh-usugli
# Processing Record 34 of Set 8 | ecija
# Processing Record 35 of Set 8 | biscarrosse
# Processing Record 36 of Set 8 | maniitsoq
# Processing Record 37 of Set 8 | ust-koksa
# Processing Record 38 of Set 8 | guiglo
# Processing Record 39 of Set 8 | barra do garcas
# Processing Record 40 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 41 of Set 8 | marshalltown
# Processing Record 42 of Set 8 | puerto baquerizo moreno
# Processing Record 43 of Set 8 | gazanjyk
# Processing Record 44 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | adilabad
# Processing Record 47 of Set 8 | pontes e lacerda
# Processing Record 48 of Set 8 | bathsheba
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | kasongo-lunda
# Processing Record 1 of Set 9 | half moon bay
# Processing Record 2 of Set 9 | kloulklubed
# Processing Record 3 of Set 9 | bullhead city
# Processing Record 4 of Set 9 | ensley
# Processing Record 5 of Set 9 | maragogi
# Processing Record 6 of Set 9 | novobirilyussy
# Processing Record 7 of Set 9 | shubarshi
# Processing Record 8 of Set 9 | tandalti
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | varhaug
# Processing Record 11 of Set 9 | andalan
# Processing Record 12 of Set 9 | ust-ishim
# Processing Record 13 of Set 9 | safranbolu
# Processing Record 14 of Set 9 | pacifica
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | storforshei
# Processing Record 17 of Set 9 | assiniboia
# Processing Record 18 of Set 9 | berlevag
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 21 of Set 9 | sakakah
# Processing Record 22 of Set 9 | rotterdam
# Processing Record 23 of Set 9 | longyearbyen
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | maua
# Processing Record 26 of Set 9 | general roca
# Processing Record 27 of Set 9 | wakkanai
# Processing Record 28 of Set 9 | lukaya
# Processing Record 29 of Set 9 | khasan
# Processing Record 30 of Set 9 | san quintin
# Processing Record 31 of Set 9 | livny
# Processing Record 32 of Set 9 | hami
# Processing Record 33 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 9 | gharghoda
# Processing Record 35 of Set 9 | moengo
# Processing Record 36 of Set 9 | calama
# Processing Record 37 of Set 9 | dukhovshchina
# Processing Record 38 of Set 9 | joensuu
# Processing Record 39 of Set 9 | abu samrah
# Processing Record 40 of Set 9 | georgetown
# Processing Record 41 of Set 9 | mahenge
# Processing Record 42 of Set 9 | nieuwpoort
# Processing Record 43 of Set 9 | trelew
# Processing Record 44 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 9 | russell
# Processing Record 46 of Set 9 | kem
# Processing Record 47 of Set 9 | tigil
# Processing Record 48 of Set 9 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 49 of Set 9 | sibolga
# Processing Record 50 of Set 9 | jiwani
# Processing Record 1 of Set 10 | tres arroyos
# Processing Record 2 of Set 10 | svetlaya
# Processing Record 3 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 4 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 10 | vendome
# Processing Record 6 of Set 10 | nuuk
# Processing Record 7 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 8 of Set 10 | rocha
# Processing Record 9 of Set 10 | castelo do piaui
# Processing Record 10 of Set 10 | bo
# City not found. Skipping...
# Processing Record 11 of Set 10 | sabya
# Processing Record 12 of Set 10 | villa oliva
# City not found. Skipping...
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | san felipe
# Processing Record 15 of Set 10 | bossembele
# City not found. Skipping...
# Processing Record 16 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 17 of Set 10 | labelle
# Processing Record 18 of Set 10 | maine-soroa
# Processing Record 19 of Set 10 | mizdah
# Processing Record 20 of Set 10 | okakarara
# Processing Record 21 of Set 10 | sinnar
# Processing Record 22 of Set 10 | ayr
# Processing Record 23 of Set 10 | keflavik
# Processing Record 24 of Set 10 | bambous virieux
# Processing Record 25 of Set 10 | reidsville
# Processing Record 26 of Set 10 | kuragino
# Processing Record 27 of Set 10 | paraiso
# Processing Record 28 of Set 10 | makung
# City not found. Skipping...
# Processing Record 29 of Set 10 | puri
# Processing Record 30 of Set 10 | nouadhibou
# Processing Record 31 of Set 10 | santa rosa
# Processing Record 32 of Set 10 | meybod
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 10 | hobyo
# Processing Record 36 of Set 10 | santa cruz de la palma
# Processing Record 37 of Set 10 | buin
# Processing Record 38 of Set 10 | petropavl
# Processing Record 39 of Set 10 | mujiayingzi
# Processing Record 40 of Set 10 | ongandjera
# Processing Record 41 of Set 10 | uarini
# Processing Record 42 of Set 10 | meghri
# Processing Record 43 of Set 10 | baykit
# Processing Record 44 of Set 10 | maceio
# Processing Record 45 of Set 10 | kapuskasing
# Processing Record 46 of Set 10 | takoradi
# Processing Record 47 of Set 10 | chum phae
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | san cristobal
# Processing Record 50 of Set 10 | vaitape
# Processing Record 1 of Set 11 | emerald
# Processing Record 2 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 11 | omsukchan
# Processing Record 4 of Set 11 | uray
# Processing Record 5 of Set 11 | tilichiki
# Processing Record 6 of Set 11 | awjilah
# Processing Record 7 of Set 11 | vanimo
# Processing Record 8 of Set 11 | flinders
# Processing Record 9 of Set 11 | montrose
# Processing Record 10 of Set 11 | caraguatatuba
# Processing Record 11 of Set 11 | marienburg
# Processing Record 12 of Set 11 | gumdag
# Processing Record 13 of Set 11 | komsomolskiy
# Processing Record 14 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 11 | barranca
# Processing Record 16 of Set 11 | alamos
# Processing Record 17 of Set 11 | palmer
# Processing Record 18 of Set 11 | ostersund
# Processing Record 19 of Set 11 | mayahi
# Processing Record 20 of Set 11 | ous
# Processing Record 21 of Set 11 | tual
# Processing Record 22 of Set 11 | cuenca
# Processing Record 23 of Set 11 | beloha
# Processing Record 24 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 11 | wellington
# Processing Record 26 of Set 11 | urusha
# Processing Record 27 of Set 11 | manokwari
# Processing Record 28 of Set 11 | piacabucu
# Processing Record 29 of Set 11 | porto santo
# Processing Record 30 of Set 11 | oussouye
# Processing Record 31 of Set 11 | vila velha
# Processing Record 32 of Set 11 | brigantine
# Processing Record 33 of Set 11 | tatawin
# Processing Record 34 of Set 11 | alofi
# Processing Record 35 of Set 11 | zdvinsk
# Processing Record 36 of Set 11 | muravlenko
# Processing Record 37 of Set 11 | san andres
# Processing Record 38 of Set 11 | soe
# Processing Record 39 of Set 11 | comodoro rivadavia
# Processing Record 40 of Set 11 | umm kaddadah
# Processing Record 41 of Set 11 | patacamaya
# Processing Record 42 of Set 11 | bandar
# Processing Record 43 of Set 11 | acari
# Processing Record 44 of Set 11 | sobolevo
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | ngunguru
# Processing Record 47 of Set 11 | ust-maya
# Processing Record 48 of Set 11 | fredericton
# Processing Record 49 of Set 11 | berdigestyakh
# Processing Record 50 of Set 11 | shitkino
# Processing Record 1 of Set 12 | valdivia
# Processing Record 2 of Set 12 | huarmey
# Processing Record 3 of Set 12 | ostrovnoy
# Processing Record 4 of Set 12 | evinayong
# Processing Record 5 of Set 12 | xai-xai
# Processing Record 6 of Set 12 | vostok
# Processing Record 7 of Set 12 | knysna
# Processing Record 8 of Set 12 | rudbar
# Processing Record 9 of Set 12 | buraydah
# Processing Record 10 of Set 12 | madang
# Processing Record 11 of Set 12 | vila franca do campo
# Processing Record 12 of Set 12 | port lincoln
# Processing Record 13 of Set 12 | ouango
# Processing Record 14 of Set 12 | mandalgarh
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | revda
# Processing Record 17 of Set 12 | yelniki
# Processing Record 18 of Set 12 | wilmington
# Processing Record 19 of Set 12 | begoro
# Processing Record 20 of Set 12 | guaruja
# Processing Record 21 of Set 12 | worcester
# Processing Record 22 of Set 12 | sheridan
# Processing Record 23 of Set 12 | yatou
# Processing Record 24 of Set 12 | ixtapa
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | caravelas
# Processing Record 27 of Set 12 | fort nelson
# Processing Record 28 of Set 12 | manono
# Processing Record 29 of Set 12 | burica
# City not found. Skipping...
# Processing Record 30 of Set 12 | spirovo
# Processing Record 31 of Set 12 | centralia
# Processing Record 32 of Set 12 | la paz
# Processing Record 33 of Set 12 | balkhash
# Processing Record 34 of Set 12 | illapel
# Processing Record 35 of Set 12 | novaci
# Processing Record 36 of Set 12 | mayor pablo lagerenza
# Processing Record 37 of Set 12 | chekhov
# Processing Record 38 of Set 12 | panama city
# Processing Record 39 of Set 12 | oxford
# Processing Record 40 of Set 12 | oron
# Processing Record 41 of Set 12 | oruro
# Processing Record 42 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 12 | byron bay
# Processing Record 45 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 46 of Set 12 | chebarkul
# Processing Record 47 of Set 12 | chumikan
# Processing Record 48 of Set 12 | broome
# Processing Record 49 of Set 12 | san ramon
# Processing Record 50 of Set 12 | cururupu
# Processing Record 1 of Set 13 | kirkwall
# Processing Record 2 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 13 | arlit
# Processing Record 4 of Set 13 | kanashevo
# Processing Record 5 of Set 13 | dudinka
# Processing Record 6 of Set 13 | abu kamal
# Processing Record 7 of Set 13 | capitao poco
# Processing Record 8 of Set 13 | farafangana
# Processing Record 9 of Set 13 | manzil kamil
# Processing Record 10 of Set 13 | syracuse
# Processing Record 11 of Set 13 | makakilo city
# Processing Record 12 of Set 13 | isabela
# Processing Record 13 of Set 13 | leningradskiy
# Processing Record 14 of Set 13 | gander
# Processing Record 15 of Set 13 | kokoda
# Processing Record 16 of Set 13 | brae
# Processing Record 17 of Set 13 | rehoboth
# Processing Record 18 of Set 13 | lagoa
# Processing Record 19 of Set 13 | isagarh
# Processing Record 20 of Set 13 | kyra
# Processing Record 21 of Set 13 | ejido
# Processing Record 22 of Set 13 | paita
# Processing Record 23 of Set 13 | dhaka
# Processing Record 24 of Set 13 | khani
# Processing Record 25 of Set 13 | kyzyl
# Processing Record 26 of Set 13 | koster
# Processing Record 27 of Set 13 | kimbe
# Processing Record 28 of Set 13 | aripuana
# Processing Record 29 of Set 13 | sironj
# Processing Record 30 of Set 13 | muisne
# Processing Record 31 of Set 13 | kendari
# Processing Record 32 of Set 13 | skelleftea
# Processing Record 33 of Set 13 | luwuk
# Processing Record 34 of Set 13 | pacific grove
# Processing Record 35 of Set 13 | fayetteville
# Processing Record 36 of Set 13 | tejutla
# Processing Record 37 of Set 13 | husavik
# Processing Record 38 of Set 13 | catuday
# Processing Record 39 of Set 13 | acapulco
# Processing Record 40 of Set 13 | dunedin
# Processing Record 41 of Set 13 | huntsville
# Processing Record 42 of Set 13 | marsaxlokk
# Processing Record 43 of Set 13 | visnes
# Processing Record 44 of Set 13 | homer
# Processing Record 45 of Set 13 | horsham
# Processing Record 46 of Set 13 | bonavista
# Processing Record 47 of Set 13 | inta
# Processing Record 48 of Set 13 | barmer
# Processing Record 49 of Set 13 | port hardy
# Processing Record 50 of Set 13 | radhanpur
# Processing Record 1 of Set 14 | lloydminster
# Processing Record 2 of Set 14 | ketchikan
# Processing Record 3 of Set 14 | smolenka
# Processing Record 4 of Set 14 | kondinskoye
# Processing Record 5 of Set 14 | sorland
# Processing Record 6 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 7 of Set 14 | minervino murge
# Processing Record 8 of Set 14 | obo
# Processing Record 9 of Set 14 | walvis bay
# Processing Record 10 of Set 14 | doha
# Processing Record 11 of Set 14 | xunchang
# Processing Record 12 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 14 | punta alta
# Processing Record 14 of Set 14 | roura
# Processing Record 15 of Set 14 | bafoulabe
# Processing Record 16 of Set 14 | katsuura
# Processing Record 17 of Set 14 | nipawin
# Processing Record 18 of Set 14 | mazagao
# Processing Record 19 of Set 14 | lexington park
# Processing Record 20 of Set 14 | adwa
# Processing Record 21 of Set 14 | maldonado
# Processing Record 22 of Set 14 | trinidad
# Processing Record 23 of Set 14 | de-kastri
# Processing Record 24 of Set 14 | kudahuvadhoo
# Processing Record 25 of Set 14 | la ronge
# Processing Record 26 of Set 14 | tynda
# Processing Record 27 of Set 14 | odienne
# Processing Record 28 of Set 14 | tomatlan
# Processing Record 29 of Set 14 | kenai
# Processing Record 30 of Set 14 | moree
# Processing Record 31 of Set 14 | daloa
# Processing Record 32 of Set 14 | aranos
# Processing Record 33 of Set 14 | houma
# Processing Record 34 of Set 14 | rudnogorsk
# Processing Record 35 of Set 14 | port augusta
# Processing Record 36 of Set 14 | mwingi
# Processing Record 37 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 14 | hurghada
# Processing Record 39 of Set 14 | oskemen
# Processing Record 40 of Set 14 | lakatoro
# Processing Record 41 of Set 14 | ranfurly
# Processing Record 42 of Set 14 | kazanskaya
# Processing Record 43 of Set 14 | zhaoyuan
# Processing Record 44 of Set 14 | turukhansk
# Processing Record 45 of Set 14 | steinbach
# Processing Record 46 of Set 14 | kushima
# Processing Record 47 of Set 14 | alice springs
# Processing Record 48 of Set 14 | yerbogachen
# Processing Record 49 of Set 14 | diapaga
# Processing Record 50 of Set 14 | kokopo
# Processing Record 1 of Set 15 | obeliai
# Processing Record 2 of Set 15 | lerwick
# Processing Record 3 of Set 15 | moose factory
# Processing Record 4 of Set 15 | mount isa
# Processing Record 5 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 6 of Set 15 | kurchum
# Processing Record 7 of Set 15 | boa esperanca
# Processing Record 8 of Set 15 | altamira
# Processing Record 9 of Set 15 | luanda
# Processing Record 10 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 15 | henties bay
# Processing Record 12 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 13 of Set 15 | la rioja
# Processing Record 14 of Set 15 | tigre
# Processing Record 15 of Set 15 | coahuayana
# Processing Record 16 of Set 15 | guantanamo
# Processing Record 17 of Set 15 | esmeralda
# Processing Record 18 of Set 15 | flin flon
# Processing Record 19 of Set 15 | koslan
# Processing Record 20 of Set 15 | amqui
# Processing Record 21 of Set 15 | faya
# Processing Record 22 of Set 15 | deputatskiy
# Processing Record 23 of Set 15 | bridlington
# Processing Record 24 of Set 15 | maningrida
# Processing Record 25 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 15 | florencia
# Processing Record 27 of Set 15 | xapuri
# Processing Record 28 of Set 15 | san bartolome de tirajana
# Processing Record 29 of Set 15 | taywarah
# Processing Record 30 of Set 15 | morehead
# Processing Record 31 of Set 15 | nefteyugansk
# Processing Record 32 of Set 15 | mitsamiouli
# Processing Record 33 of Set 15 | santiago de cao
# Processing Record 34 of Set 15 | bairnsdale
# Processing Record 35 of Set 15 | marovoay
# Processing Record 36 of Set 15 | puka
# Processing Record 37 of Set 15 | colesberg
# Processing Record 38 of Set 15 | benguela
# Processing Record 39 of Set 15 | sungaipenuh
# Processing Record 40 of Set 15 | diego de almagro
# Processing Record 41 of Set 15 | praia da vitoria
# Processing Record 42 of Set 15 | hearst
# Processing Record 43 of Set 15 | todos santos
# Processing Record 44 of Set 15 | pontevedra
# Processing Record 45 of Set 15 | shu
# Processing Record 46 of Set 15 | imabari
# City not found. Skipping...
# Processing Record 47 of Set 15 | raga
# Processing Record 48 of Set 15 | kieta
# Processing Record 49 of Set 15 | salisbury
# Processing Record 50 of Set 15 | bristol
# Processing Record 1 of Set 16 | olinda
# Processing Record 2 of Set 16 | rundu
# Processing Record 3 of Set 16 | surt
# Processing Record 4 of Set 16 | nioro
# Processing Record 5 of Set 16 | donghai
# Processing Record 6 of Set 16 | uyemskiy
# Processing Record 7 of Set 16 | esso
# Processing Record 8 of Set 16 | sandy bay
# Processing Record 9 of Set 16 | viransehir
# Processing Record 10 of Set 16 | faribault
# Processing Record 11 of Set 16 | san rafael
# Processing Record 12 of Set 16 | masyaf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Khandyga  62.67  135.60     13.59        86          98        2.10
# 1    Derzhavinsk  51.10   66.32     35.35        90         100       21.39
# 2      Bangassou   4.74   22.82     69.71        90         100        2.30
# 3        Methoni  36.82   21.70     64.99        82           0        4.70
# 4        Rikitea -23.12 -134.97     75.34        85         100       19.24
# ..           ...    ...     ...       ...       ...         ...         ...
# 697    Sandy Bay -42.91  147.35     51.80        53          75        4.70
# 698   Viransehir  37.24   39.76     65.57        26          90        3.24
# 699    Faribault  44.30  -93.27     28.40        63          90        8.05
# 700   San Rafael -34.62  -68.33     78.35        18          28       20.94
# 701       Masyaf  35.07   36.34     77.00        22           0        2.24
#
#     Country                 Date Current Description
# 0        RU  2020-10-26 20:27:49     overcast clouds
# 1        KZ  2020-10-26 20:27:49     overcast clouds
# 2        CF  2020-10-26 20:27:49     overcast clouds
# 3        GR  2020-10-26 20:27:50           clear sky
# 4        PF  2020-10-26 20:27:50          light rain
# ..      ...                  ...                 ...
# 697      AU  2020-10-26 20:31:22       broken clouds
# 698      TR  2020-10-26 20:31:23     overcast clouds
# 699      US  2020-10-26 20:31:23     overcast clouds
# 700      AR  2020-10-26 20:30:35    scattered clouds
# 701      SY  2020-10-26 20:31:23           clear sky
#
# [702 rows x 10 columns]

# %%
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv', index = False)

# %%
# The rest of the code is for testing purposes 
# only to understand what the code is doing above.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         city_weather_description = city_weather["weather"][0]["description"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date,
#                          "Current Description": city_weather_description})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khandyga
# Processing Record 2 of Set 1 | derzhavinsk
# Processing Record 3 of Set 1 | bangassou
# Processing Record 4 of Set 1 | methoni
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | miandrivazo
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | port hedland
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | kaitangata
# Processing Record 14 of Set 1 | hirara
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | chicama
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | guadalajara
# Processing Record 20 of Set 1 | strezhevoy
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | akureyri
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | podyuga
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | mangrol
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | inuvik
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | inhambane
# Processing Record 32 of Set 1 | uvinza
# Processing Record 33 of Set 1 | luderitz
# Processing Record 34 of Set 1 | taolanaro
# Processing Record 35 of Set 1 | lavrentiya
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | nizhneyansk
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | kuche
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | jinxiang
# Processing Record 45 of Set 1 | sidi ali
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | barentsburg
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | nyrob
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | den helder
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | saint-augustin
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | illoqqortoormiut
# Processing Record 9 of Set 2 | necochea
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | rio gallegos
# Processing Record 12 of Set 2 | quthing
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | ahipara
# Processing Record 15 of Set 2 | moses lake
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | daimiel
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | amderma
# Processing Record 21 of Set 2 | kahului
# Processing Record 22 of Set 2 | huixtla
# Processing Record 23 of Set 2 | norsup
# Processing Record 24 of Set 2 | meyungs
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | esperance
# Processing Record 31 of Set 2 | okato
# Processing Record 32 of Set 2 | tumannyy
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | baloda
# Processing Record 35 of Set 2 | gigmoto
# Processing Record 36 of Set 2 | ajdabiya
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | vestmannaeyjar
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | posse
# Processing Record 42 of Set 2 | progreso
# Processing Record 43 of Set 2 | itupiranga
# Processing Record 44 of Set 2 | kamenskoye
# Processing Record 45 of Set 2 | port moresby
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | rio grande
# Processing Record 50 of Set 2 | chapleau
# Processing Record 1 of Set 3 | ayan
# Processing Record 2 of Set 3 | merauke
# Processing Record 3 of Set 3 | champasak
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | carutapera
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | lewisporte
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | chiredzi
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | pamplona
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | jumla
# Processing Record 15 of Set 3 | bitung
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | axim
# Processing Record 18 of Set 3 | mangai
# Processing Record 19 of Set 3 | sinnamary
# Processing Record 20 of Set 3 | tibiri
# Processing Record 21 of Set 3 | lorengau
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | baruun-urt
# Processing Record 24 of Set 3 | sola
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | kulhudhuffushi
# Processing Record 27 of Set 3 | daru
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | vavoua
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | sigli
# Processing Record 33 of Set 3 | iquique
# Processing Record 34 of Set 3 | richards bay
# Processing Record 35 of Set 3 | yoichi
# Processing Record 36 of Set 3 | avarua
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | ishigaki
# Processing Record 39 of Set 3 | barahona
# Processing Record 40 of Set 3 | taoudenni
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | hualmay
# Processing Record 43 of Set 3 | hermanus
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | marshall
# Processing Record 46 of Set 3 | tsihombe
# Processing Record 47 of Set 3 | matagami
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | port-gentil
# Processing Record 50 of Set 3 | banjar
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | coquimbo
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | tokur
# Processing Record 5 of Set 4 | belushya guba
# Processing Record 6 of Set 4 | leua
# Processing Record 7 of Set 4 | elko
# Processing Record 8 of Set 4 | custoias
# Processing Record 9 of Set 4 | ipeti
# Processing Record 10 of Set 4 | kamenka
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | pingzhuang
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | ituporanga
# Processing Record 16 of Set 4 | cap-haitien
# Processing Record 17 of Set 4 | margate
# Processing Record 18 of Set 4 | semme
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | vilyuysk
# Processing Record 21 of Set 4 | khor
# Processing Record 22 of Set 4 | ballina
# Processing Record 23 of Set 4 | marica
# Processing Record 24 of Set 4 | zhigansk
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | havre-saint-pierre
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | katobu
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | douglas
# Processing Record 31 of Set 4 | sao filipe
# Processing Record 32 of Set 4 | srednekolymsk
# Processing Record 33 of Set 4 | peniche
# Processing Record 34 of Set 4 | toora-khem
# Processing Record 35 of Set 4 | lakes entrance
# Processing Record 36 of Set 4 | san vicente
# Processing Record 37 of Set 4 | tha chang
# Processing Record 38 of Set 4 | vaitupu
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | tabiauea
# Processing Record 41 of Set 4 | hobart
# Processing Record 42 of Set 4 | pangai
# Processing Record 43 of Set 4 | te anau
# Processing Record 44 of Set 4 | mayachnyy
# Processing Record 45 of Set 4 | sucre
# Processing Record 46 of Set 4 | puerto lopez
# Processing Record 47 of Set 4 | belyy yar
# Processing Record 48 of Set 4 | vaini
# Processing Record 49 of Set 4 | rapid city
# Processing Record 50 of Set 4 | shelburne
# Processing Record 1 of Set 5 | aba
# Processing Record 2 of Set 5 | aykhal
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | caucaia
# Processing Record 5 of Set 5 | catamarca
# Processing Record 6 of Set 5 | high level
# Processing Record 7 of Set 5 | beidao
# Processing Record 8 of Set 5 | lardos
# Processing Record 9 of Set 5 | tabas
# Processing Record 10 of Set 5 | grand river south east
# Processing Record 11 of Set 5 | palabuhanratu
# Processing Record 12 of Set 5 | kabinda
# Processing Record 13 of Set 5 | prince rupert
# Processing Record 14 of Set 5 | clinton
# Processing Record 15 of Set 5 | aras
# Processing Record 16 of Set 5 | jasper
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | kismayo
# Processing Record 19 of Set 5 | port stanley
# Processing Record 20 of Set 5 | airai
# Processing Record 21 of Set 5 | kenora
# Processing Record 22 of Set 5 | gat
# Processing Record 23 of Set 5 | saint anthony
# Processing Record 24 of Set 5 | ferrol
# Processing Record 25 of Set 5 | dodge city
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | barcelos
# Processing Record 28 of Set 5 | hervey bay
# Processing Record 29 of Set 5 | ucluelet
# Processing Record 30 of Set 5 | suhbaatar
# Processing Record 31 of Set 5 | virginia beach
# Processing Record 32 of Set 5 | amurzet
# Processing Record 33 of Set 5 | that phanom
# Processing Record 34 of Set 5 | otane
# Processing Record 35 of Set 5 | mys shmidta
# Processing Record 36 of Set 5 | tolaga bay
# Processing Record 37 of Set 5 | bay roberts
# Processing Record 38 of Set 5 | cusuna
# Processing Record 39 of Set 5 | oktyabrskiy
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | puerto carreno
# Processing Record 42 of Set 5 | abiy adi
# Processing Record 43 of Set 5 | saint-joseph
# Processing Record 44 of Set 5 | port-cartier
# Processing Record 45 of Set 5 | udachnyy
# Processing Record 46 of Set 5 | fortuna
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | pontianak
# Processing Record 49 of Set 5 | sar-e pul
# Processing Record 50 of Set 5 | lolua
# Processing Record 1 of Set 6 | hovd
# Processing Record 2 of Set 6 | camacha
# Processing Record 3 of Set 6 | siverek
# Processing Record 4 of Set 6 | miandoab
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | corinto
# Processing Record 8 of Set 6 | sampit
# Processing Record 9 of Set 6 | chara
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | tasiilaq
# Processing Record 12 of Set 6 | lephepe
# Processing Record 13 of Set 6 | la orilla
# Processing Record 14 of Set 6 | dicabisagan
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | lesnoy
# Processing Record 17 of Set 6 | qaanaaq
# Processing Record 18 of Set 6 | sakaiminato
# Processing Record 19 of Set 6 | hambantota
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | cayenne
# Processing Record 22 of Set 6 | kattivakkam
# Processing Record 23 of Set 6 | riacho de santana
# Processing Record 24 of Set 6 | kaeo
# Processing Record 25 of Set 6 | egersund
# Processing Record 26 of Set 6 | nijar
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | waipawa
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | north platte
# Processing Record 32 of Set 6 | ginda
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | xining
# Processing Record 35 of Set 6 | touros
# Processing Record 36 of Set 6 | atar
# Processing Record 37 of Set 6 | sabang
# Processing Record 38 of Set 6 | sao paulo de olivenca
# Processing Record 39 of Set 6 | dikson
# Processing Record 40 of Set 6 | marion
# Processing Record 41 of Set 6 | umzimvubu
# Processing Record 42 of Set 6 | bagdarin
# Processing Record 43 of Set 6 | raudeberg
# Processing Record 44 of Set 6 | port hawkesbury
# Processing Record 45 of Set 6 | jalu
# Processing Record 46 of Set 6 | preston
# Processing Record 47 of Set 6 | sembakung
# Processing Record 48 of Set 6 | ternate
# Processing Record 49 of Set 6 | yunjinghong
# Processing Record 50 of Set 6 | aiquile
# Processing Record 1 of Set 7 | arraial do cabo
# Processing Record 2 of Set 7 | kirakira
# Processing Record 3 of Set 7 | randolph
# Processing Record 4 of Set 7 | joshimath
# Processing Record 5 of Set 7 | teno
# Processing Record 6 of Set 7 | yuci
# Processing Record 7 of Set 7 | seymchan
# Processing Record 8 of Set 7 | yichun
# Processing Record 9 of Set 7 | sao felix do xingu
# Processing Record 10 of Set 7 | eureka
# Processing Record 11 of Set 7 | probolinggo
# Processing Record 12 of Set 7 | nelson bay
# Processing Record 13 of Set 7 | itoman
# Processing Record 14 of Set 7 | egvekinot
# Processing Record 15 of Set 7 | iquitos
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | prado
# Processing Record 18 of Set 7 | hwange
# Processing Record 19 of Set 7 | shakhtinsk
# Processing Record 20 of Set 7 | san-pedro
# Processing Record 21 of Set 7 | zwedru
# Processing Record 22 of Set 7 | taksimo
# Processing Record 23 of Set 7 | harper
# Processing Record 24 of Set 7 | noyon
# Processing Record 25 of Set 7 | bilma
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | alekseyevsk
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | seoul
# Processing Record 30 of Set 7 | biloela
# Processing Record 31 of Set 7 | ponta do sol
# Processing Record 32 of Set 7 | jiexiu
# Processing Record 33 of Set 7 | golden
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | qaqortoq
# Processing Record 36 of Set 7 | faanui
# Processing Record 37 of Set 7 | talnakh
# Processing Record 38 of Set 7 | bonneville
# Processing Record 39 of Set 7 | camana
# Processing Record 40 of Set 7 | spitsevka
# Processing Record 41 of Set 7 | marsh harbour
# Processing Record 42 of Set 7 | tadine
# Processing Record 43 of Set 7 | stepnogorsk
# Processing Record 44 of Set 7 | ravar
# Processing Record 45 of Set 7 | itarema
# Processing Record 46 of Set 7 | bontang
# Processing Record 47 of Set 7 | nova venecia
# Processing Record 48 of Set 7 | rosarito
# Processing Record 49 of Set 7 | duz
# Processing Record 50 of Set 7 | nizhniy mamon
# Processing Record 1 of Set 8 | klaksvik
# Processing Record 2 of Set 8 | charters towers
# Processing Record 3 of Set 8 | kwinana
# Processing Record 4 of Set 8 | kaniama
# Processing Record 5 of Set 8 | manzhouli
# Processing Record 6 of Set 8 | sangar
# Processing Record 7 of Set 8 | puerto leguizamo
# Processing Record 8 of Set 8 | marcona
# Processing Record 9 of Set 8 | tonekabon
# Processing Record 10 of Set 8 | noumea
# Processing Record 11 of Set 8 | artyom
# Processing Record 12 of Set 8 | shadegan
# Processing Record 13 of Set 8 | plettenberg bay
# Processing Record 14 of Set 8 | attawapiskat
# Processing Record 15 of Set 8 | luganville
# Processing Record 16 of Set 8 | sentyabrskiy
# Processing Record 17 of Set 8 | samusu
# Processing Record 18 of Set 8 | altay
# Processing Record 19 of Set 8 | arman
# Processing Record 20 of Set 8 | waounde
# Processing Record 21 of Set 8 | butterworth
# Processing Record 22 of Set 8 | tautira
# Processing Record 23 of Set 8 | saint-pierre
# Processing Record 24 of Set 8 | bargal
# Processing Record 25 of Set 8 | marzuq
# Processing Record 26 of Set 8 | gimli
# Processing Record 27 of Set 8 | grand centre
# Processing Record 28 of Set 8 | konevo
# Processing Record 29 of Set 8 | bose
# Processing Record 30 of Set 8 | atambua
# Processing Record 31 of Set 8 | wanning
# Processing Record 32 of Set 8 | aflu
# Processing Record 33 of Set 8 | verkh-usugli
# Processing Record 34 of Set 8 | ecija
# Processing Record 35 of Set 8 | biscarrosse
# Processing Record 36 of Set 8 | maniitsoq
# Processing Record 37 of Set 8 | ust-koksa
# Processing Record 38 of Set 8 | guiglo
# Processing Record 39 of Set 8 | barra do garcas
# Processing Record 40 of Set 8 | tuggurt
# Processing Record 41 of Set 8 | marshalltown
# Processing Record 42 of Set 8 | puerto baquerizo moreno
# Processing Record 43 of Set 8 | gazanjyk
# Processing Record 44 of Set 8 | jiroft
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | adilabad
# Processing Record 47 of Set 8 | pontes e lacerda
# Processing Record 48 of Set 8 | bathsheba
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | kasongo-lunda
# Processing Record 1 of Set 9 | half moon bay
# Processing Record 2 of Set 9 | kloulklubed
# Processing Record 3 of Set 9 | bullhead city
# Processing Record 4 of Set 9 | ensley
# Processing Record 5 of Set 9 | maragogi
# Processing Record 6 of Set 9 | novobirilyussy
# Processing Record 7 of Set 9 | shubarshi
# Processing Record 8 of Set 9 | tandalti
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | varhaug
# Processing Record 11 of Set 9 | andalan
# Processing Record 12 of Set 9 | ust-ishim
# Processing Record 13 of Set 9 | safranbolu
# Processing Record 14 of Set 9 | pacifica
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | storforshei
# Processing Record 17 of Set 9 | assiniboia
# Processing Record 18 of Set 9 | berlevag
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | macaboboni
# Processing Record 21 of Set 9 | sakakah
# Processing Record 22 of Set 9 | rotterdam
# Processing Record 23 of Set 9 | longyearbyen
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | maua
# Processing Record 26 of Set 9 | general roca
# Processing Record 27 of Set 9 | wakkanai
# Processing Record 28 of Set 9 | lukaya
# Processing Record 29 of Set 9 | khasan
# Processing Record 30 of Set 9 | san quintin
# Processing Record 31 of Set 9 | livny
# Processing Record 32 of Set 9 | hami
# Processing Record 33 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 9 | gharghoda
# Processing Record 35 of Set 9 | moengo
# Processing Record 36 of Set 9 | calama
# Processing Record 37 of Set 9 | dukhovshchina
# Processing Record 38 of Set 9 | joensuu
# Processing Record 39 of Set 9 | abu samrah
# Processing Record 40 of Set 9 | georgetown
# Processing Record 41 of Set 9 | mahenge
# Processing Record 42 of Set 9 | nieuwpoort
# Processing Record 43 of Set 9 | trelew
# Processing Record 44 of Set 9 | rawannawi
# Processing Record 45 of Set 9 | russell
# Processing Record 46 of Set 9 | kem
# Processing Record 47 of Set 9 | tigil
# Processing Record 48 of Set 9 | krasnoyarsk-45
# Processing Record 49 of Set 9 | sibolga
# Processing Record 50 of Set 9 | jiwani
# Processing Record 1 of Set 10 | tres arroyos
# Processing Record 2 of Set 10 | svetlaya
# Processing Record 3 of Set 10 | cazaje
# Processing Record 4 of Set 10 | saleaula
# Processing Record 5 of Set 10 | vendome
# Processing Record 6 of Set 10 | nuuk
# Processing Record 7 of Set 10 | katsiveli
# Processing Record 8 of Set 10 | rocha
# Processing Record 9 of Set 10 | castelo do piaui
# Processing Record 10 of Set 10 | bo
# Processing Record 11 of Set 10 | sabya
# Processing Record 12 of Set 10 | villa oliva
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | san felipe
# Processing Record 15 of Set 10 | bossembele
# Processing Record 16 of Set 10 | buariki
# Processing Record 17 of Set 10 | labelle
# Processing Record 18 of Set 10 | maine-soroa
# Processing Record 19 of Set 10 | mizdah
# Processing Record 20 of Set 10 | okakarara
# Processing Record 21 of Set 10 | sinnar
# Processing Record 22 of Set 10 | ayr
# Processing Record 23 of Set 10 | keflavik
# Processing Record 24 of Set 10 | bambous virieux
# Processing Record 25 of Set 10 | reidsville
# Processing Record 26 of Set 10 | kuragino
# Processing Record 27 of Set 10 | paraiso
# Processing Record 28 of Set 10 | makung
# Processing Record 29 of Set 10 | puri
# Processing Record 30 of Set 10 | nouadhibou
# Processing Record 31 of Set 10 | santa rosa
# Processing Record 32 of Set 10 | meybod
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | jabiru
# Processing Record 35 of Set 10 | hobyo
# Processing Record 36 of Set 10 | santa cruz de la palma
# Processing Record 37 of Set 10 | buin
# Processing Record 38 of Set 10 | petropavl
# Processing Record 39 of Set 10 | mujiayingzi
# Processing Record 40 of Set 10 | ongandjera
# Processing Record 41 of Set 10 | uarini
# Processing Record 42 of Set 10 | meghri
# Processing Record 43 of Set 10 | baykit
# Processing Record 44 of Set 10 | maceio
# Processing Record 45 of Set 10 | kapuskasing
# Processing Record 46 of Set 10 | takoradi
# Processing Record 47 of Set 10 | chum phae
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | san cristobal
# Processing Record 50 of Set 10 | vaitape
# Processing Record 1 of Set 11 | emerald
# Processing Record 2 of Set 11 | ust-kamchatsk
# Processing Record 3 of Set 11 | omsukchan
# Processing Record 4 of Set 11 | uray
# Processing Record 5 of Set 11 | tilichiki
# Processing Record 6 of Set 11 | awjilah
# Processing Record 7 of Set 11 | vanimo
# Processing Record 8 of Set 11 | flinders
# Processing Record 9 of Set 11 | montrose
# Processing Record 10 of Set 11 | caraguatatuba
# Processing Record 11 of Set 11 | marienburg
# Processing Record 12 of Set 11 | gumdag
# Processing Record 13 of Set 11 | komsomolskiy
# Processing Record 14 of Set 11 | satitoa
# Processing Record 15 of Set 11 | barranca
# Processing Record 16 of Set 11 | alamos
# Processing Record 17 of Set 11 | palmer
# Processing Record 18 of Set 11 | ostersund
# Processing Record 19 of Set 11 | mayahi
# Processing Record 20 of Set 11 | ous
# Processing Record 21 of Set 11 | tual
# Processing Record 22 of Set 11 | cuenca
# Processing Record 23 of Set 11 | beloha
# Processing Record 24 of Set 11 | longlac
# Processing Record 25 of Set 11 | wellington
# Processing Record 26 of Set 11 | urusha
# Processing Record 27 of Set 11 | manokwari
# Processing Record 28 of Set 11 | piacabucu
# Processing Record 29 of Set 11 | porto santo
# Processing Record 30 of Set 11 | oussouye
# Processing Record 31 of Set 11 | vila velha
# Processing Record 32 of Set 11 | brigantine
# Processing Record 33 of Set 11 | tatawin
# Processing Record 34 of Set 11 | alofi
# Processing Record 35 of Set 11 | zdvinsk
# Processing Record 36 of Set 11 | muravlenko
# Processing Record 37 of Set 11 | san andres
# Processing Record 38 of Set 11 | soe
# Processing Record 39 of Set 11 | comodoro rivadavia
# Processing Record 40 of Set 11 | umm kaddadah
# Processing Record 41 of Set 11 | patacamaya
# Processing Record 42 of Set 11 | bandar
# Processing Record 43 of Set 11 | acari
# Processing Record 44 of Set 11 | sobolevo
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | ngunguru
# Processing Record 47 of Set 11 | ust-maya
# Processing Record 48 of Set 11 | fredericton
# Processing Record 49 of Set 11 | berdigestyakh
# Processing Record 50 of Set 11 | shitkino
# Processing Record 1 of Set 12 | valdivia
# Processing Record 2 of Set 12 | huarmey
# Processing Record 3 of Set 12 | ostrovnoy
# Processing Record 4 of Set 12 | evinayong
# Processing Record 5 of Set 12 | xai-xai
# Processing Record 6 of Set 12 | vostok
# Processing Record 7 of Set 12 | knysna
# Processing Record 8 of Set 12 | rudbar
# Processing Record 9 of Set 12 | buraydah
# Processing Record 10 of Set 12 | madang
# Processing Record 11 of Set 12 | vila franca do campo
# Processing Record 12 of Set 12 | port lincoln
# Processing Record 13 of Set 12 | ouango
# Processing Record 14 of Set 12 | mandalgarh
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | revda
# Processing Record 17 of Set 12 | yelniki
# Processing Record 18 of Set 12 | wilmington
# Processing Record 19 of Set 12 | begoro
# Processing Record 20 of Set 12 | guaruja
# Processing Record 21 of Set 12 | worcester
# Processing Record 22 of Set 12 | sheridan
# Processing Record 23 of Set 12 | yatou
# Processing Record 24 of Set 12 | ixtapa
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | caravelas
# Processing Record 27 of Set 12 | fort nelson
# Processing Record 28 of Set 12 | manono
# Processing Record 29 of Set 12 | burica
# Processing Record 30 of Set 12 | spirovo
# Processing Record 31 of Set 12 | centralia
# Processing Record 32 of Set 12 | la paz
# Processing Record 33 of Set 12 | balkhash
# Processing Record 34 of Set 12 | illapel
# Processing Record 35 of Set 12 | novaci
# Processing Record 36 of Set 12 | mayor pablo lagerenza
# Processing Record 37 of Set 12 | chekhov
# Processing Record 38 of Set 12 | panama city
# Processing Record 39 of Set 12 | oxford
# Processing Record 40 of Set 12 | oron
# Processing Record 41 of Set 12 | oruro
# Processing Record 42 of Set 12 | nguiu
# Processing Record 43 of Set 12 | fort saint john
# Processing Record 44 of Set 12 | byron bay
# Processing Record 45 of Set 12 | maloshuyka
# Processing Record 46 of Set 12 | chebarkul
# Processing Record 47 of Set 12 | chumikan
# Processing Record 48 of Set 12 | broome
# Processing Record 49 of Set 12 | san ramon
# Processing Record 50 of Set 12 | cururupu
# Processing Record 1 of Set 13 | kirkwall
# Processing Record 2 of Set 13 | halalo
# Processing Record 3 of Set 13 | arlit
# Processing Record 4 of Set 13 | kanashevo
# Processing Record 5 of Set 13 | dudinka
# Processing Record 6 of Set 13 | abu kamal
# Processing Record 7 of Set 13 | capitao poco
# Processing Record 8 of Set 13 | farafangana
# Processing Record 9 of Set 13 | manzil kamil
# Processing Record 10 of Set 13 | syracuse
# Processing Record 11 of Set 13 | makakilo city
# Processing Record 12 of Set 13 | isabela
# Processing Record 13 of Set 13 | leningradskiy
# Processing Record 14 of Set 13 | gander
# Processing Record 15 of Set 13 | kokoda
# Processing Record 16 of Set 13 | brae
# Processing Record 17 of Set 13 | rehoboth
# Processing Record 18 of Set 13 | lagoa
# Processing Record 19 of Set 13 | isagarh
# Processing Record 20 of Set 13 | kyra
# Processing Record 21 of Set 13 | ejido
# Processing Record 22 of Set 13 | paita
# Processing Record 23 of Set 13 | dhaka
# Processing Record 24 of Set 13 | khani
# Processing Record 25 of Set 13 | kyzyl
# Processing Record 26 of Set 13 | koster
# Processing Record 27 of Set 13 | kimbe
# Processing Record 28 of Set 13 | aripuana
# Processing Record 29 of Set 13 | sironj
# Processing Record 30 of Set 13 | muisne
# Processing Record 31 of Set 13 | kendari
# Processing Record 32 of Set 13 | skelleftea
# Processing Record 33 of Set 13 | luwuk
# Processing Record 34 of Set 13 | pacific grove
# Processing Record 35 of Set 13 | fayetteville
# Processing Record 36 of Set 13 | tejutla
# Processing Record 37 of Set 13 | husavik
# Processing Record 38 of Set 13 | catuday
# Processing Record 39 of Set 13 | acapulco
# Processing Record 40 of Set 13 | dunedin
# Processing Record 41 of Set 13 | huntsville
# Processing Record 42 of Set 13 | marsaxlokk
# Processing Record 43 of Set 13 | visnes
# Processing Record 44 of Set 13 | homer
# Processing Record 45 of Set 13 | horsham
# Processing Record 46 of Set 13 | bonavista
# Processing Record 47 of Set 13 | inta
# Processing Record 48 of Set 13 | barmer
# Processing Record 49 of Set 13 | port hardy
# Processing Record 50 of Set 13 | radhanpur
# Processing Record 1 of Set 14 | lloydminster
# Processing Record 2 of Set 14 | ketchikan
# Processing Record 3 of Set 14 | smolenka
# Processing Record 4 of Set 14 | kondinskoye
# Processing Record 5 of Set 14 | sorland
# Processing Record 6 of Set 14 | toftir
# Processing Record 7 of Set 14 | minervino murge
# Processing Record 8 of Set 14 | obo
# Processing Record 9 of Set 14 | walvis bay
# Processing Record 10 of Set 14 | doha
# Processing Record 11 of Set 14 | xunchang
# Processing Record 12 of Set 14 | sorvag
# Processing Record 13 of Set 14 | punta alta
# Processing Record 14 of Set 14 | roura
# Processing Record 15 of Set 14 | bafoulabe
# Processing Record 16 of Set 14 | katsuura
# Processing Record 17 of Set 14 | nipawin
# Processing Record 18 of Set 14 | mazagao
# Processing Record 19 of Set 14 | lexington park
# Processing Record 20 of Set 14 | adwa
# Processing Record 21 of Set 14 | maldonado
# Processing Record 22 of Set 14 | trinidad
# Processing Record 23 of Set 14 | de-kastri
# Processing Record 24 of Set 14 | kudahuvadhoo
# Processing Record 25 of Set 14 | la ronge
# Processing Record 26 of Set 14 | tynda
# Processing Record 27 of Set 14 | odienne
# Processing Record 28 of Set 14 | tomatlan
# Processing Record 29 of Set 14 | kenai
# Processing Record 30 of Set 14 | moree
# Processing Record 31 of Set 14 | daloa
# Processing Record 32 of Set 14 | aranos
# Processing Record 33 of Set 14 | houma
# Processing Record 34 of Set 14 | rudnogorsk
# Processing Record 35 of Set 14 | port augusta
# Processing Record 36 of Set 14 | mwingi
# Processing Record 37 of Set 14 | utiroa
# Processing Record 38 of Set 14 | hurghada
# Processing Record 39 of Set 14 | oskemen
# Processing Record 40 of Set 14 | lakatoro
# Processing Record 41 of Set 14 | ranfurly
# Processing Record 42 of Set 14 | kazanskaya
# Processing Record 43 of Set 14 | zhaoyuan
# Processing Record 44 of Set 14 | turukhansk
# Processing Record 45 of Set 14 | steinbach
# Processing Record 46 of Set 14 | kushima
# Processing Record 47 of Set 14 | alice springs
# Processing Record 48 of Set 14 | yerbogachen
# Processing Record 49 of Set 14 | diapaga
# Processing Record 50 of Set 14 | kokopo
# Processing Record 1 of Set 15 | obeliai
# Processing Record 2 of Set 15 | lerwick
# Processing Record 3 of Set 15 | moose factory
# Processing Record 4 of Set 15 | mount isa
# Processing Record 5 of Set 15 | uwayl
# Processing Record 6 of Set 15 | kurchum
# Processing Record 7 of Set 15 | boa esperanca
# Processing Record 8 of Set 15 | altamira
# Processing Record 9 of Set 15 | luanda
# Processing Record 10 of Set 15 | ngukurr
# Processing Record 11 of Set 15 | henties bay
# Processing Record 12 of Set 15 | haapu
# Processing Record 13 of Set 15 | la rioja
# Processing Record 14 of Set 15 | tigre
# Processing Record 15 of Set 15 | coahuayana
# Processing Record 16 of Set 15 | guantanamo
# Processing Record 17 of Set 15 | esmeralda
# Processing Record 18 of Set 15 | flin flon
# Processing Record 19 of Set 15 | koslan
# Processing Record 20 of Set 15 | amqui
# Processing Record 21 of Set 15 | faya
# Processing Record 22 of Set 15 | deputatskiy
# Processing Record 23 of Set 15 | bridlington
# Processing Record 24 of Set 15 | maningrida
# Processing Record 25 of Set 15 | ruatoria
# Processing Record 26 of Set 15 | florencia
# Processing Record 27 of Set 15 | xapuri
# Processing Record 28 of Set 15 | san bartolome de tirajana
# Processing Record 29 of Set 15 | taywarah
# Processing Record 30 of Set 15 | morehead
# Processing Record 31 of Set 15 | nefteyugansk
# Processing Record 32 of Set 15 | mitsamiouli
# Processing Record 33 of Set 15 | santiago de cao
# Processing Record 34 of Set 15 | bairnsdale
# Processing Record 35 of Set 15 | marovoay
# Processing Record 36 of Set 15 | puka
# Processing Record 37 of Set 15 | colesberg
# Processing Record 38 of Set 15 | benguela
# Processing Record 39 of Set 15 | sungaipenuh
# Processing Record 40 of Set 15 | diego de almagro
# Processing Record 41 of Set 15 | praia da vitoria
# Processing Record 42 of Set 15 | hearst
# Processing Record 43 of Set 15 | todos santos
# Processing Record 44 of Set 15 | pontevedra
# Processing Record 45 of Set 15 | shu
# Processing Record 46 of Set 15 | imabari
# Processing Record 47 of Set 15 | raga
# Processing Record 48 of Set 15 | kieta
# Processing Record 49 of Set 15 | salisbury
# Processing Record 50 of Set 15 | bristol
# Processing Record 1 of Set 16 | olinda
# Processing Record 2 of Set 16 | rundu
# Processing Record 3 of Set 16 | surt
# Processing Record 4 of Set 16 | nioro
# Processing Record 5 of Set 16 | donghai
# Processing Record 6 of Set 16 | uyemskiy
# Processing Record 7 of Set 16 | esso
# Processing Record 8 of Set 16 | sandy bay
# Processing Record 9 of Set 16 | viransehir
# Processing Record 10 of Set 16 | faribault
# Processing Record 11 of Set 16 | san rafael
# Processing Record 12 of Set 16 | masyaf

# %%
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=67f5ffdc9f3b9208f2d054e49f2d721d&q=masyaf'

# %%
#Run an API request for each of the cities.
try:
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    # Parse out the needed data.
    city_lat = city_weather["coord"]["lat"]
    city_lng = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_country = city_weather["sys"]["country"]
    city_weather_description = city_weather["weather"][0]["description"]
    # Convert the date to ISO standard.
    city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
    city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Date": city_date,
                     "Current Description": city_weather_description})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()

# %%
city_weather
# Out:
# {'coord': {'lon': 36.34, 'lat': 35.07},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 77,
#   'feels_like': 72.66,
#   'temp_min': 77,
#   'temp_max': 77,
#   'pressure': 1013,
#   'humidity': 22},
#  'visibility': 10000,
#  'wind': {'speed': 2.24, 'deg': 50},
#  'clouds': {'all': 0},
#  'dt': 1603744283,
#  'sys': {'type': 1,
#   'id': 7613,
#   'country': 'SY',
#   'sunrise': 1603684215,
#   'sunset': 1603723600},
#  'timezone': 10800,
#  'id': 167046,
#  'name': 'Maşyāf',
#  'cod': 200}

# %%
type(city_weather)
# Out:
# dict

# %%
test_var = city_weather['weather']

# %%
len(city_weather['weather'])
# Out:
# 1

# %%
test_var[0]
# Out:
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}

# %%
test_var_2 = city_weather['weather'][0]

# %%
test_var_2
# Out:
# {'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}

# %%
type(test_var_2)
# Out:
# dict

# %%
test_var_2['description']
# Out:
# 'clear sky'

# %%
city_weather['weather'][0]['description']
# Out:
# 'clear sky'
