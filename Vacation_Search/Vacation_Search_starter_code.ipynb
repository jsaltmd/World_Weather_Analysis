# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Khandyga  62.67  135.60     13.59        86          98        2.10
# 1  Derzhavinsk  51.10   66.32     35.35        90         100       21.39
# 2    Bangassou   4.74   22.82     69.71        90         100        2.30
# 3      Methoni  36.82   21.70     64.99        82           0        4.70
# 4      Rikitea -23.12 -134.97     75.34        85         100       19.24
#
#   Country                 Date Current Description
# 0      RU  2020-10-26 20:27:49     overcast clouds
# 1      KZ  2020-10-26 20:27:49     overcast clouds
# 2      CF  2020-10-26 20:27:49     overcast clouds
# 3      GR  2020-10-26 20:27:50           clear sky
# 4      PF  2020-10-26 20:27:50          light rain

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 4       Rikitea -23.12 -134.97     75.34        85         100       19.24
# 5     Kavaratti  10.57   72.64     82.42        72          81        7.00
# 6   Miandrivazo -19.52   45.47     78.82        62           0        5.66
# 13       Hirara  24.80  125.28     76.62        70          94       15.95
# 15       Castro -24.79  -50.01     72.09        70         100        7.16
# 18  Guadalajara  20.67 -103.33     88.00        23          40        0.83
# 22     Souillac -20.52   57.52     73.40        73          40       10.29
# 23       Rawson -43.30  -65.10     71.13        29         100       17.83
# 26      Mangrol  21.12   70.12     82.18        63           0        1.72
# 27    Hithadhoo  -0.60   73.08     83.16        66          17        6.53
#
#    Country                 Date Current Description
# 4       PF  2020-10-26 20:27:50          light rain
# 5       IN  2020-10-26 20:27:50       broken clouds
# 6       MG  2020-10-26 20:27:50           clear sky
# 13      JP  2020-10-26 20:27:52     overcast clouds
# 15      BR  2020-10-26 20:23:31     overcast clouds
# 18      MX  2020-10-26 20:25:50    scattered clouds
# 22      MU  2020-10-26 20:27:53    scattered clouds
# 23      AR  2020-10-26 20:27:54     overcast clouds
# 26      IN  2020-10-26 20:27:54           clear sky
# 27      MV  2020-10-26 20:27:54          few clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City                   264
# Lat                    264
# Lng                    264
# Max Temp               264
# Humidity               264
# Cloudiness             264
# Wind Speed             264
# Country                259
# Date                   264
# Current Description    264
# dtype: int64

# %%
#testing
temp_filter = ((city_data_df['Max Temp'] <= max_temp) 
                   & (city_data_df['Max Temp'] >= min_temp))
test_cities_df = city_data_df.loc[temp_filter]

# %%
temp_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 697    False
# 698    False
# 699    False
# 700     True
# 701     True
# Name: Max Temp, Length: 702, dtype: bool

# %%
#testing
null_filter = test_cities_df['Country'].isnull()#.all(axis=1)
test_cities_df.loc[null_filter, :]
# Out:
#            City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 427   Okakarara -20.58  17.43     78.30        31          99       19.06
# 445  Ongandjera -17.88  15.07     78.51        26          25       11.63
# 564    Rehoboth -23.32  17.08     76.95        28          97       10.33
# 627      Aranos -24.13  19.12     73.60        40          55       10.54
# 691       Rundu -17.93  19.77     76.03        19           0        4.68
#
#     Country                 Date Current Description
# 427     NaN  2020-10-26 20:30:00     overcast clouds
# 445     NaN  2020-10-26 20:30:11    scattered clouds
# 564     NaN  2020-10-26 20:30:45     overcast clouds
# 627     NaN  2020-10-26 20:31:02       broken clouds
# 691     NaN  2020-10-26 20:31:20           clear sky

# %%
test_cities_df.count()
# Out:
# City                   264
# Lat                    264
# Lng                    264
# Max Temp               264
# Humidity               264
# Cloudiness             264
# Wind Speed             264
# Country                259
# Date                   264
# Current Description    264
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)].dropna()
preferred_cities_df.count()
# Out:
# City                   259
# Lat                    259
# Lng                    259
# Max Temp               259
# Humidity               259
# Cloudiness             259
# Wind Speed             259
# Country                259
# Date                   259
# Current Description    259
# dtype: int64

# %%
# 5a. Create DataFrame called clean_hotel_df to store hotel names along with city, country, max temp, and coordinates.
clean_hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
clean_hotel_df["Hotel Name"] = ""
clean_hotel_df.head(10)
# Out:
#            City Country  Max Temp Current Description    Lat     Lng  \
# 4       Rikitea      PF     75.34          light rain -23.12 -134.97
# 5     Kavaratti      IN     82.42       broken clouds  10.57   72.64
# 6   Miandrivazo      MG     78.82           clear sky -19.52   45.47
# 13       Hirara      JP     76.62     overcast clouds  24.80  125.28
# 15       Castro      BR     72.09     overcast clouds -24.79  -50.01
# 18  Guadalajara      MX     88.00    scattered clouds  20.67 -103.33
# 22     Souillac      MU     73.40    scattered clouds -20.52   57.52
# 23       Rawson      AR     71.13     overcast clouds -43.30  -65.10
# 26      Mangrol      IN     82.18           clear sky  21.12   70.12
# 27    Hithadhoo      MV     83.16          few clouds  -0.60   73.08
#
#    Hotel Name
# 4
# 5
# 6
# 13
# 15
# 18
# 22
# 23
# 26
# 27

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in clean_hotel_df.iterrows():
    
# 6c. Get latitude and longitude from DataFrame

    lat = row["Lat"] 
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
        
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        clean_hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"] 
        print(hotels["results"][0]["name"])
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Pension Maro'i
# Hotels in Lakshadweep Islands
# Hôtel Arc En Ciel Miandrivazo
# Hotel Atoll Emerald Miyakojima
# CHACARA BAILLY
# Hotel Aranzazú
# Bils' Villa
# Hotel Punta León
# Hotel The Royal Honours
# Scoop Guest House
# Oceano
# HAMDAN PLAZA HOTEL
# Finch Bay Galapagos Hotel
# Villa Enata
# Sheraton Kauai Resort at Coconut Beach
# Shandrani Beachcomber Resort & Spa
# Grage Hotel Bengkulu
# Mini Hotel Central
# Maui Seaside Hotel
# Hotel Jardin Real
# Nabelchel Bungalows
# Hilo Hawaiian Hotel
# Ganesh Anand Catering services Baloda
# Cj's Travellers Inn
# الحاج سليمان الشترة
# Pousada das Palmeiras
# Playa Linda Hotel
# Lamana Hotel
# Hotel not found... skipping.
# Kiat Ngong Wetland BUNGALOW
# Chambres d'hôte "La Trinité"
# Lidera
# The Nesbitt Arms
# Isles Sunset Lodge
# Peoplesight Learning Center ( PLC )
# AXIM BEACH RESORT AND SPA
# Hotel not found... skipping.
# ALETHEIA Appartement Sinnamary
# Hotel not found... skipping.
# Lorengau Harbourside Hotel
# Ulkel Guest House
# Volcano Sea View Tree House
# Haajy Guest House 1
# New century hotel
# Camp Pasica
# Hotel La Sougoun
# Hotel Riza
# Paradise Inn
# Hotel Peace Land Ishigakijima
# Hotel Caribe
# Hotel not found... skipping.
# Lake Guntersville Bed and Breakfast
# Fengshui Residence
# The Hamsa Resort
# Hotel Jacaré
# Habitation Jouissant
# Marica Hills
# La Ode Husein
# Tortuga B&B
# สุริยาค้าไม้
# Ha'apai Beach Resort
# Resguardo Indigena Maguare
# Keleti Beach Resort
# Mickeys Guest House
# M.O.S. Logística - Filial Fortaleza
# Amerian Catamarca Park Hotel
# Lindos Princess Beach Hotel
# Village Mianda Mutole
# Nuli Sapi
# Agan-Hotel
# OlusHome
# Shelly Bay Resort
# Hotel not found... skipping.
# Casa Hotel Victoria
# "Plantation Bed and Breakfast
# Super 8 by Wyndham Fortuna
# Valle Aridane
# Aston Pontianak Hotel & Convention Center
# Mercan Hotel
# Hôtel & Restaurant DIANA Ambilobe
# Aquarius Boutique Hotel Sampit
# Baymont by Wyndham Lazaro Cardenas
# Nancy Montanes Bernardo
# Pousada Porto De Canoas
# Bungalow 63
# Hôtel Le Dronmi
# St. Joseph Thirumana mandapam
# Nosso Hotel
# Sur Plaza Hotel
# Hostal San Isidro Oficial
# INN NEW HORIZON
# Hotel Citra
# Jalu Hotel
# Hotel not found... skipping.
# Grand Dafam Bela Ternate
# Pousada Porto Praia
# SanBiz Lodge
# Villa Cordillera
# Apart Hotel Rio Xingu
# Eureka Inn Trademark By Wyndham
# OYO 1639 Penginapan Anggrek Syariah 1
# Southern Beach Hotel & Resort Okinawa
# INN CORNER RIVER - PRADO - BAHIA - HOUSING AND HOTEL
# Hwange Colliery Guest House
# Hotel Maria
# Elijah Worjloh
# Screensaver
# Expeditions Ténére voyages
# Holiday Inn Express & Suites Elk Grove Central - Hwy 99
# Hotel not found... skipping.
# Nusa Island Retreat
# Bora-Bora Pearl Beach Resort & Spa
# Abaco Beach Resort
# Hotel not found... skipping.
# Windvillage
# Okra Leaf Guest House Syariah
# Vitoria,es
# Hotel Festival Plaza Rosarito
# Cattleman's Rest Motor Inn
# Hôtel Le Lagon
# The Espiritu Hotel
# Hotel not found... skipping.
# Cititel Penang
# Pension Oaoa
# Lindsey Hôtel
# Pondok Pesantren Al Muhajirin Atambua
# Paradise Hotel
# domicile de boubé TTK
# Hotel Pousada Tropical
# Hotel los Algarrobos
# Dwaraka Hotel.
# Hotel Bressan
# Atlantis Hotel
# Hotel not found... skipping.
# The Ritz-Carlton, Half Moon Bay
# Storyboard Beach Resort
# Holiday Inn Express & Suites Pensacola W I-10
# Salinas do Maragogi All Inclusive Resort
# Hotel not found... skipping.
# Pacifica Lighthouse, Trademark Collection by Wyndham
# Osprey Beach Hotel
# Fakhamat Al Orjoana Apartment
# Hotel Capriccio Mauá
# Hotel El Recreo
# Jageshwer House
# Masanga
# Park Hotel Calama
# Hotel not found... skipping.
# Cititel Penang
# Hotel Touring Club
# Macs
# Hotel Syariah CN Darussalam
# Al Mumtaz Transport Jiwani
# Habitacion Triple con baño y entrada privada
# Aseel Hotel Apartment
# Derogongan Residence
# Posada Llovizna Rodríguez
# La Belle Motel
# Hotel not found... skipping.
# Okahitua, Omaboro City
# فندق الرشيد
# Casa Tia Villa
# Rinconcito Verde
# OYO 1577 Hotel Shree Hari Grand
# El Medina
# Erlyn’s Sta Rosa City Home
# Osmani Hotel
# H10 Taburiente Playa
# Paihuen
# Onesto Guesthouse
# Mercure Maceio Pajucara Hotel
# Raybow International Hotel
# Major Grand
# Pirineos
# Conrad Bora Bora Nui
# Vahmoneh Lodge Vanimo
# Cibele Cass
# Luz del Sol
# Hotel not found... skipping.
# Grand Vilia Hotel
# Hotel Cuenca
# Swiss Belhotel Manokwari
# Piaçabuçu News
# Auberge du Routard
# Hotel Vitória Palace
# Taloa Heights
# Hotel Arena Blanca
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hospedaje Ximens
# Platinum Hotel
# Comfort Inn Hotel
# Hotel not found... skipping.
# Hotel Ballast Wilmington, Tapestry Collection by Hilton
# MR ODAME
# Charme Hotel Guarujá
# Container Inn Puerto Vallarta
# Casa Laguna, Bed & Breakfast
# Pousada dos Navegantes
# Hotel hewa bora
# Hotel Londres
# Hotel not found... skipping.
# Trump International Hotel & Tower Panama
# Aqua Belloni Lodge
# San Ramon Marriott
# Pousada Través'cia
# Hôtel Telwa Bungalow
# Hotel New Tokyo
# Boukarra Ali
# Marriott's Ko Olina Beach Club
# Isawad Resort
# Daito Guest House
# Noble Luminous Accommodation
# Bora Bora Nails & Spa C.A.
# Hotel Náutico de Paita
# FARS Hotel & Resorts
# Kimbe Bay Hotel
# shri shyam palace sironj
# Quinta Samay
# Hotel Wixel
# Hotel Santika Luwuk
# Lovers Point Inn
# American Eagle Inn
# Casa en venta Las Cruces Tejutla San Marcos
# GResort
# HS Hotsson Smart Acapulco
# Embassy Suites by Hilton Huntsville Hotel & Spa
# OYO 71911 Hotel Amber Palace
# YASH HOTEL
# Doha Marriott Hotel
# Center Hotel Punta Alta
# Amazonie Découverte SARL
# Hotel not found... skipping.
# Kudahuvadhoo Retreat
# Oustaz Vame DIAKITE
# Norma franco
# Imans Hotel Daloa
# Ley-Lia Guest House
# Courtyard by Marriott Houma
# Sea Star Beau Rivage Hotel
# Lakatoro Palm Lodge
# Hotel not found... skipping.
# Kokopo Beach Bungalow Resort
# JHS Palace Hotel
# EPIC SANA Luanda
# Puerto Delta Apartamentos
# Hotel Los Arcos
# Hotel Marti
# campismo las palmas
# Dhukurrdji Lodge
# Hotel Viverde Las Tirajanas
# Foyer ADM
# Hotel not found... skipping.
# Hotel Praia Morena
# hotel luna del desierto
# Hotel California Todos Santos
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel 5 Sóis
# Millennia Estate
# City Hotel
# Hotel not found... skipping.
# Hotel San Rafael
# Hotel restaurants and tourist Misyaf

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df.head(10)
# Out:
#            City Country  Max Temp Current Description    Lat     Lng  \
# 4       Rikitea      PF     75.34          light rain -23.12 -134.97
# 5     Kavaratti      IN     82.42       broken clouds  10.57   72.64
# 6   Miandrivazo      MG     78.82           clear sky -19.52   45.47
# 13       Hirara      JP     76.62     overcast clouds  24.80  125.28
# 15       Castro      BR     72.09     overcast clouds -24.79  -50.01
# 18  Guadalajara      MX     88.00    scattered clouds  20.67 -103.33
# 22     Souillac      MU     73.40    scattered clouds -20.52   57.52
# 23       Rawson      AR     71.13     overcast clouds -43.30  -65.10
# 26      Mangrol      IN     82.18           clear sky  21.12   70.12
# 27    Hithadhoo      MV     83.16          few clouds  -0.60   73.08
#
#                         Hotel Name
# 4                   Pension Maro'i
# 5    Hotels in Lakshadweep Islands
# 6    Hôtel Arc En Ciel Miandrivazo
# 13  Hotel Atoll Emerald Miyakojima
# 15                  CHACARA BAILLY
# 18                  Hotel Aranzazú
# 22                     Bils' Villa
# 23                Hotel Punta León
# 26         Hotel The Royal Honours
# 27               Scoop Guest House

# %%
# 8a. Create the output File (CSV)
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# test
test_df = hotel_df.iloc[0:2,  :]#.to_frame()
type(test_df)
test_df.columns
# Out:
# Index(['City', 'Country', 'Max Temp', 'Current Description', 'Lat', 'Lng',
#        'Hotel Name'],
#       dtype='object')

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

test_df = hotel_df.iloc[0:2,  :]#.to_frame()
# 6b. Iterate through the hotel DataFrame.
for index, row in test_df.iterrows():
# # 6c. Get latitude and longitude from DataFrame

    lat = row["Lat"] 
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
         
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    print(hotels)
    print('\n\n')
#     # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
#     try:
#         hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
#     except (IndexError):
#         print("Hotel not found... skipping.")
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -23.1206197, 'lng': -134.9687529}, 'viewport': {'northeast': {'lat': -23.1194598197085, 'lng': -134.9673886697085}, 'southwest': {'lat': -23.1221577802915, 'lng': -134.9700866302915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': "Pension Maro'i", 'opening_hours': {'open_now': True}, 'photos': [{'height': 2304, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111098332724302207930">luigia b.</a>'], 'photo_reference': 'CmRaAAAA2CUkDf1kM_qfvgI-3qn41I8ee0S4Gu3bJ0KVYoKEcuVFJipvaaxPkpaQTHubfSeyp58H59HRk01zG2STHuN7-w1xkqploA8LL4716UpdyOfvLQBmMcU4kivnHgPy_z6FEhB1wRKwvsISHMisZBqL0i7qGhSwLA1IMpzIqeiN_CbA3b_AMfNipg', 'width': 4096}], 'place_id': 'ChIJnW6Jh0aIJ54RV2HnC1r0Hjw', 'plus_code': {'global_code': '5487V2HJ+QF'}, 'rating': 4, 'reference': 'ChIJnW6Jh0aIJ54RV2HnC1r0Hjw', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 17, 'vicinity': 'Rikitea'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -23.1276524, 'lng': -134.9656596}, 'viewport': {'northeast': {'lat': -23.1263721197085, 'lng': -134.9643507197085}, 'southwest': {'lat': -23.1290700802915, 'lng': -134.9670486802915}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Pension Bianca & Benoit', 'photos': [{'height': 2048, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115150439809622095143">Frédérick B.</a>'], 'photo_reference': 'CmRaAAAAz6fWZDfDwJ9B7hsxBdM-y-eueEarsLDysU0nVedqGPsc0Q-JU-QRV8qgtxs42w6zMJgWJDZbCSPCXfIPfXIhjxCSk5jWsnNPsR5o5iZw0WFLCtlnj3GBXFv-0NbdPw5NEhCflDb3rQJYBhqOBfl86ve-GhQXiXddxHjuzBbvbLnxX4rCFRrbew', 'width': 1536}], 'place_id': 'ChIJib4T7laIJ54RcJ1rUHQ9KXk', 'plus_code': {'global_code': '5487V2CM+WP'}, 'rating': 4.6, 'reference': 'ChIJib4T7laIJ54RcJ1rUHQ9KXk', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 11, 'vicinity': 'BP 19 | Archipel des Gambier, Mangareva'}], 'status': 'OK'}
#
#
#
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 10.576452, 'lng': 72.63839899999999}, 'viewport': {'northeast': {'lat': 10.5777839802915, 'lng': 72.63975628029151}, 'southwest': {'lat': 10.5750860197085, 'lng': 72.6370583197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': 'Hotels in Lakshadweep Islands', 'photos': [{'height': 3120, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111663554856309879399">Mohammed Mukthar</a>'], 'photo_reference': 'CmRaAAAAaqOiYT_ywGsKPFJWhPtLy66DBTZVwvHw91ezHyIBdW0Jg9_5dGe_vwwvjQkPhMWbHur16NgWcuRTUXgbHu4XUcCItaqD_em0hFCfjJrR5t4Ye4oQZz92nfydvFmazyUBEhBD4JehrzSGwYF2KWRcAuHAGhRSs9WO6Z4m_dTjUXKI_-_bgqrsKw', 'width': 4160}], 'place_id': 'ChIJNR_2MfVLnjsRS_ntamzgXdM', 'plus_code': {'compound_code': 'HJGQ+H9 Kavaratti, Lakshadweep, India', 'global_code': '7J2JHJGQ+H9'}, 'rating': 4.5, 'reference': 'ChIJNR_2MfVLnjsRS_ntamzgXdM', 'scope': 'GOOGLE', 'types': ['travel_agency', 'lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 12, 'vicinity': 'Kavaratti'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 10.570591, 'lng': 72.6381459}, 'viewport': {'northeast': {'lat': 10.5719051302915, 'lng': 72.6396029302915}, 'southwest': {'lat': 10.5692071697085, 'lng': 72.63690496970848}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Bismillah Hotel And Lodging', 'photos': [{'height': 2340, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109711403738218755191">Sudhir M M</a>'], 'photo_reference': 'CmRaAAAA7K_SH0J51ELDHEFQjsr_THhtK3RshH415O43RQoi55sFTTWDxbAwCA8OabHQmJvdcgdVfZIt_n3KW7rDQg5c6wYcicfd_5D-UPrW-KTqmNcf27xGpqSlAbENH4EfNCKiEhCUsPit0pnSoFrBdI8ZBl4yGhQ8uj8BXR3iFS8TG5-uVQmfN7HdoQ', 'width': 4160}], 'place_id': 'ChIJ49TIKPNLnjsRnMV7AF6F2R4', 'plus_code': {'compound_code': 'HJCQ+67 Kavaratti, Lakshadweep, India', 'global_code': '7J2JHJCQ+67'}, 'rating': 4, 'reference': 'ChIJ49TIKPNLnjsRnMV7AF6F2R4', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 82, 'vicinity': 'Kavaratti'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 10.570731, 'lng': 72.63779989999999}, 'viewport': {'northeast': {'lat': 10.5720024302915, 'lng': 72.63910808029149}, 'southwest': {'lat': 10.5693044697085, 'lng': 72.63641011970849}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Passenger Hall', 'photos': [{'height': 2304, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107674225309004796152">Anoob Antony</a>'], 'photo_reference': 'CmRaAAAAOG5EZWnC2hT8kUmhh7CLejXoiQ1A63f7eCal7upy_25v8Y-Qa_tlTJQMCTtwEBlopHf-zLCHGCW1zTZu5kF6oOakZqZ0-p1rzS30Mc0ewkTCAWj3C4JhZPWhyEv1inuBEhCex-DOAjeJBPTnG5E1aORDGhQaec5bHebsX6y9pHsi5iauEqjyrQ', 'width': 4096}], 'place_id': 'ChIJBbBRJPNLnjsR5PokOJ8lV8Y', 'plus_code': {'compound_code': 'HJCQ+74 Kavaratti, Lakshadweep, India', 'global_code': '7J2JHJCQ+74'}, 'rating': 4, 'reference': 'ChIJBbBRJPNLnjsR5PokOJ8lV8Y', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 70, 'vicinity': 'Kavaratti'}, {'business_status': 'CLOSED_TEMPORARILY', 'geometry': {'location': {'lat': 10.5707756, 'lng': 72.637192}, 'viewport': {'northeast': {'lat': 10.5721538802915, 'lng': 72.6385584302915}, 'southwest': {'lat': 10.5694559197085, 'lng': 72.63586046970849}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'name': 'Tah paradise hut, Kavaratti', 'permanently_closed': True, 'place_id': 'ChIJg6hXmepLnjsRTSxpZvJPMQg', 'plus_code': {'compound_code': 'HJCP+8V Kavaratti, Lakshadweep, India', 'global_code': '7J2JHJCP+8V'}, 'reference': 'ChIJg6hXmepLnjsRTSxpZvJPMQg', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'vicinity': 'Tah paradise hut re ...

# %%
hotel_df
# Out:
#             City Country  Max Temp Current Description    Lat     Lng  \
# 4        Rikitea      PF     75.34          light rain -23.12 -134.97
# 5      Kavaratti      IN     82.42       broken clouds  10.57   72.64
# 6    Miandrivazo      MG     78.82           clear sky -19.52   45.47
# 13        Hirara      JP     76.62     overcast clouds  24.80  125.28
# 15        Castro      BR     72.09     overcast clouds -24.79  -50.01
# ..           ...     ...       ...                 ...    ...     ...
# 691        Rundu     NaN     76.03           clear sky -17.93   19.77
# 692         Surt      LY     72.36           clear sky  31.21   16.59
# 693        Nioro      GM     82.87           clear sky  13.35  -15.75
# 700   San Rafael      AR     78.35    scattered clouds -34.62  -68.33
# 701       Masyaf      SY     77.00           clear sky  35.07   36.34
#
#                                Hotel Name
# 4                          Pension Maro'i
# 5           Hotels in Lakshadweep Islands
# 6           Hôtel Arc En Ciel Miandrivazo
# 13         Hotel Atoll Emerald Miyakojima
# 15                         CHACARA BAILLY
# ..                                    ...
# 691                      Millennia Estate
# 692                            City Hotel
# 693
# 700                      Hotel San Rafael
# 701  Hotel restaurants and tourist Misyaf
#
# [264 rows x 7 columns]
