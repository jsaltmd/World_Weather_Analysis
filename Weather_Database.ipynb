# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5db1bc44a69ffe1c11d4d822ad20bde3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kirakira
# Processing Record 2 of Set 1 | mizpe ramon
# City not found. Skipping...
# Processing Record 3 of Set 1 | waitati
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | alice
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | raudeberg
# Processing Record 8 of Set 1 | hovd
# Processing Record 9 of Set 1 | katastarion
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | grand gaube
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | mahon
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | korla
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | tecpan
# Processing Record 24 of Set 1 | qaqortoq
# Processing Record 25 of Set 1 | mae sai
# Processing Record 26 of Set 1 | quatre cocos
# Processing Record 27 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 1 | shimanovsk
# Processing Record 29 of Set 1 | vestmanna
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | coquimbo
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | saint-pierre
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | honningsvag
# Processing Record 39 of Set 1 | talnakh
# Processing Record 40 of Set 1 | eltham
# Processing Record 41 of Set 1 | tucuma
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | ipixuna
# Processing Record 45 of Set 1 | ogaminana
# Processing Record 46 of Set 1 | puro
# Processing Record 47 of Set 1 | kulhudhuffushi
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | san quintin
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | saint-georges
# Processing Record 4 of Set 2 | faya
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | slave lake
# Processing Record 8 of Set 2 | berlevag
# Processing Record 9 of Set 2 | ilhabela
# Processing Record 10 of Set 2 | mangan
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | klaksvik
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | tagbac
# Processing Record 15 of Set 2 | tura
# Processing Record 16 of Set 2 | abha
# Processing Record 17 of Set 2 | solenzo
# Processing Record 18 of Set 2 | luderitz
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | gazli
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | petropavl
# Processing Record 25 of Set 2 | afanasyevo
# City not found. Skipping...
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | jalu
# Processing Record 28 of Set 2 | deputatskiy
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 2 | clifton
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 2 | coffs harbour
# Processing Record 35 of Set 2 | ouadda
# Processing Record 36 of Set 2 | ojinaga
# Processing Record 37 of Set 2 | pa sang
# Processing Record 38 of Set 2 | palu
# Processing Record 39 of Set 2 | bintulu
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | hammerfest
# Processing Record 43 of Set 2 | lubango
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | kracheh
# City not found. Skipping...
# Processing Record 46 of Set 2 | cayenne
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | inuvik
# Processing Record 49 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | pakxan
# Processing Record 2 of Set 3 | ballina
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | kenai
# Processing Record 7 of Set 3 | rio gallegos
# Processing Record 8 of Set 3 | port macquarie
# Processing Record 9 of Set 3 | acari
# Processing Record 10 of Set 3 | bathsheba
# Processing Record 11 of Set 3 | wagar
# Processing Record 12 of Set 3 | ullapool
# Processing Record 13 of Set 3 | aswan
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | brandon
# Processing Record 18 of Set 3 | benguela
# Processing Record 19 of Set 3 | yairipok
# Processing Record 20 of Set 3 | uvat
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | inhambane
# Processing Record 23 of Set 3 | ust-kulom
# Processing Record 24 of Set 3 | komsomolskiy
# Processing Record 25 of Set 3 | lusambo
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | lagoa
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | ust-ishim
# Processing Record 30 of Set 3 | mareeba
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | ixtapa
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | elat
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | marck
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 3 | oudtshoorn
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | bilma
# Processing Record 49 of Set 3 | shubarshi
# Processing Record 50 of Set 3 | hvide sande
# Processing Record 1 of Set 4 | khandyga
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | lamu
# Processing Record 4 of Set 4 | balkhash
# Processing Record 5 of Set 4 | fairview
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 4 | chililabombwe
# Processing Record 9 of Set 4 | buin
# Processing Record 10 of Set 4 | nouadhibou
# Processing Record 11 of Set 4 | lenger
# Processing Record 12 of Set 4 | metro
# Processing Record 13 of Set 4 | northam
# Processing Record 14 of Set 4 | atasu
# Processing Record 15 of Set 4 | ketchikan
# Processing Record 16 of Set 4 | lakatoro
# Processing Record 17 of Set 4 | north bend
# Processing Record 18 of Set 4 | qasigiannguit
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | asau
# Processing Record 21 of Set 4 | caravelas
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | olafsvik
# Processing Record 24 of Set 4 | opuwo
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | balti
# Processing Record 27 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 4 | mishan
# Processing Record 29 of Set 4 | huancavelica
# Processing Record 30 of Set 4 | karratha
# Processing Record 31 of Set 4 | rehoboth
# Processing Record 32 of Set 4 | tessalit
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | quimper
# Processing Record 35 of Set 4 | kalmunai
# Processing Record 36 of Set 4 | mount isa
# Processing Record 37 of Set 4 | ola
# Processing Record 38 of Set 4 | avera
# Processing Record 39 of Set 4 | okhotsk
# Processing Record 40 of Set 4 | trelleborg
# Processing Record 41 of Set 4 | chifeng
# Processing Record 42 of Set 4 | ayan
# Processing Record 43 of Set 4 | suez
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | marawi
# Processing Record 47 of Set 4 | anloga
# Processing Record 48 of Set 4 | vila velha
# Processing Record 49 of Set 4 | eyrarbakki
# Processing Record 50 of Set 4 | baijiantan
# Processing Record 1 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 3 of Set 5 | nurota
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | selizharovo
# Processing Record 6 of Set 5 | bidar
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | shelburne
# Processing Record 9 of Set 5 | puerto montt
# Processing Record 10 of Set 5 | mittagong
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | orocue
# Processing Record 13 of Set 5 | lanxi
# Processing Record 14 of Set 5 | sao raimundo das mangabeiras
# Processing Record 15 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 5 | padang
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | searcy
# Processing Record 21 of Set 5 | yagodnoye
# Processing Record 22 of Set 5 | port blair
# Processing Record 23 of Set 5 | maputo
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | dudinka
# Processing Record 28 of Set 5 | lata
# Processing Record 29 of Set 5 | nyurba
# Processing Record 30 of Set 5 | jumla
# Processing Record 31 of Set 5 | werda
# Processing Record 32 of Set 5 | angoche
# Processing Record 33 of Set 5 | marzuq
# Processing Record 34 of Set 5 | nadym
# Processing Record 35 of Set 5 | fort nelson
# Processing Record 36 of Set 5 | lebedyn
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | vestmannaeyjar
# Processing Record 39 of Set 5 | madang
# Processing Record 40 of Set 5 | saqqez
# Processing Record 41 of Set 5 | arlit
# Processing Record 42 of Set 5 | kosh-agach
# Processing Record 43 of Set 5 | comodoro rivadavia
# Processing Record 44 of Set 5 | havre-saint-pierre
# Processing Record 45 of Set 5 | bethel
# Processing Record 46 of Set 5 | henties bay
# Processing Record 47 of Set 5 | nizhniy kuranakh
# Processing Record 48 of Set 5 | varhaug
# Processing Record 49 of Set 5 | kuvshinovo
# Processing Record 50 of Set 5 | puerto madero
# Processing Record 1 of Set 6 | itaituba
# Processing Record 2 of Set 6 | tommot
# Processing Record 3 of Set 6 | beroroha
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | barkly west
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | skibbereen
# Processing Record 8 of Set 6 | port lincoln
# Processing Record 9 of Set 6 | yelizovo
# Processing Record 10 of Set 6 | meulaboh
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | tsiroanomandidy
# Processing Record 13 of Set 6 | magadan
# Processing Record 14 of Set 6 | mackay
# Processing Record 15 of Set 6 | xining
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | molo
# Processing Record 18 of Set 6 | anadyr
# Processing Record 19 of Set 6 | seoul
# Processing Record 20 of Set 6 | kutum
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | kotelnikovo
# Processing Record 23 of Set 6 | san andres
# Processing Record 24 of Set 6 | gizo
# Processing Record 25 of Set 6 | yerbogachen
# Processing Record 26 of Set 6 | marsabit
# Processing Record 27 of Set 6 | salvador
# Processing Record 28 of Set 6 | stokmarknes
# Processing Record 29 of Set 6 | esperance
# Processing Record 30 of Set 6 | srednekolymsk
# Processing Record 31 of Set 6 | asyut
# Processing Record 32 of Set 6 | bhatkal
# Processing Record 33 of Set 6 | fortuna
# Processing Record 34 of Set 6 | quelimane
# Processing Record 35 of Set 6 | salina cruz
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | churapcha
# Processing Record 38 of Set 6 | santa rosa
# Processing Record 39 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 40 of Set 6 | inirida
# Processing Record 41 of Set 6 | road town
# Processing Record 42 of Set 6 | sao filipe
# Processing Record 43 of Set 6 | mahebourg
# Processing Record 44 of Set 6 | tateyama
# Processing Record 45 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 6 | norwalk
# Processing Record 47 of Set 6 | kyren
# Processing Record 48 of Set 6 | medea
# Processing Record 49 of Set 6 | kurchum
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 7 | biak
# Processing Record 3 of Set 7 | barrow
# Processing Record 4 of Set 7 | olenino
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | mezica
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | knoxville
# Processing Record 9 of Set 7 | warmbad
# Processing Record 10 of Set 7 | quiindy
# Processing Record 11 of Set 7 | torbay
# Processing Record 12 of Set 7 | masallatah
# Processing Record 13 of Set 7 | dukat
# Processing Record 14 of Set 7 | palmer
# Processing Record 15 of Set 7 | aksu
# Processing Record 16 of Set 7 | steamboat springs
# Processing Record 17 of Set 7 | sanchor
# Processing Record 18 of Set 7 | obera
# Processing Record 19 of Set 7 | chibuto
# Processing Record 20 of Set 7 | ponta do sol
# Processing Record 21 of Set 7 | borogontsy
# Processing Record 22 of Set 7 | acapulco
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | saskylakh
# Processing Record 25 of Set 7 | le port
# Processing Record 26 of Set 7 | cravo norte
# Processing Record 27 of Set 7 | manakara
# Processing Record 28 of Set 7 | tarko-sale
# Processing Record 29 of Set 7 | pakaur
# Processing Record 30 of Set 7 | hofn
# Processing Record 31 of Set 7 | hualmay
# Processing Record 32 of Set 7 | bonthe
# Processing Record 33 of Set 7 | luganville
# Processing Record 34 of Set 7 | gasa
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | macas
# Processing Record 37 of Set 7 | mamallapuram
# Processing Record 38 of Set 7 | haverfordwest
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | wonthaggi
# Processing Record 41 of Set 7 | vanimo
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | mariental
# Processing Record 44 of Set 7 | balikpapan
# Processing Record 45 of Set 7 | te anau
# Processing Record 46 of Set 7 | san jose
# Processing Record 47 of Set 7 | flinders
# Processing Record 48 of Set 7 | arman
# Processing Record 49 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 7 | vikulovo
# Processing Record 1 of Set 8 | kavaratti
# Processing Record 2 of Set 8 | saint-louis
# Processing Record 3 of Set 8 | buraydah
# Processing Record 4 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 8 | mmathubudukwane
# Processing Record 6 of Set 8 | pereira barreto
# Processing Record 7 of Set 8 | awbari
# Processing Record 8 of Set 8 | roros
# Processing Record 9 of Set 8 | sault sainte marie
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | rundu
# Processing Record 12 of Set 8 | lasa
# Processing Record 13 of Set 8 | maceio
# Processing Record 14 of Set 8 | nanortalik
# Processing Record 15 of Set 8 | sheridan
# Processing Record 16 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 8 | severnyy
# Processing Record 18 of Set 8 | cherskiy
# Processing Record 19 of Set 8 | matamoros
# Processing Record 20 of Set 8 | kavieng
# Processing Record 21 of Set 8 | lipin bor
# Processing Record 22 of Set 8 | veraval
# Processing Record 23 of Set 8 | winnemucca
# Processing Record 24 of Set 8 | dixon
# Processing Record 25 of Set 8 | nome
# Processing Record 26 of Set 8 | dalbandin
# Processing Record 27 of Set 8 | minudasht
# Processing Record 28 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 29 of Set 8 | moro
# Processing Record 30 of Set 8 | ninghai
# Processing Record 31 of Set 8 | falkenberg
# Processing Record 32 of Set 8 | macia
# Processing Record 33 of Set 8 | zhoukou
# Processing Record 34 of Set 8 | nova gradiska
# Processing Record 35 of Set 8 | naze
# Processing Record 36 of Set 8 | souillac
# Processing Record 37 of Set 8 | bambanglipuro
# Processing Record 38 of Set 8 | lompoc
# Processing Record 39 of Set 8 | gambiran
# Processing Record 40 of Set 8 | doka
# Processing Record 41 of Set 8 | svetlogorsk
# Processing Record 42 of Set 8 | milkovo
# Processing Record 43 of Set 8 | tuatapere
# Processing Record 44 of Set 8 | pangnirtung
# Processing Record 45 of Set 8 | sola
# Processing Record 46 of Set 8 | ravar
# Processing Record 47 of Set 8 | hohhot
# Processing Record 48 of Set 8 | lander
# Processing Record 49 of Set 8 | manokwari
# Processing Record 50 of Set 8 | gazojak
# Processing Record 1 of Set 9 | aykhal
# Processing Record 2 of Set 9 | mporokoso
# Processing Record 3 of Set 9 | hami
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | kysyl-syr
# Processing Record 6 of Set 9 | omboue
# Processing Record 7 of Set 9 | chara
# Processing Record 8 of Set 9 | mbeya
# Processing Record 9 of Set 9 | general roca
# Processing Record 10 of Set 9 | umba
# Processing Record 11 of Set 9 | provideniya
# Processing Record 12 of Set 9 | atar
# Processing Record 13 of Set 9 | cap malheureux
# Processing Record 14 of Set 9 | wick
# Processing Record 15 of Set 9 | partizanskoye
# Processing Record 16 of Set 9 | santa cruz
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | bolgatanga
# Processing Record 19 of Set 9 | port hedland
# Processing Record 20 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 21 of Set 9 | lorengau
# Processing Record 22 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 9 | adrar
# Processing Record 24 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 9 | tsogni
# Processing Record 26 of Set 9 | buta
# Processing Record 27 of Set 9 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 28 of Set 9 | vao
# Processing Record 29 of Set 9 | toora-khem
# Processing Record 30 of Set 9 | tezu
# Processing Record 31 of Set 9 | lavrentiya
# Processing Record 32 of Set 9 | chiredzi
# Processing Record 33 of Set 9 | mehamn
# Processing Record 34 of Set 9 | ponta delgada
# Processing Record 35 of Set 9 | muros
# Processing Record 36 of Set 9 | baghdad
# Processing Record 37 of Set 9 | irbeyskoye
# Processing Record 38 of Set 9 | gazanjyk
# Processing Record 39 of Set 9 | moranbah
# Processing Record 40 of Set 9 | broken hill
# Processing Record 41 of Set 9 | mopipi
# Processing Record 42 of Set 9 | san javier
# Processing Record 43 of Set 9 | kangaatsiaq
# Processing Record 44 of Set 9 | umm lajj
# Processing Record 45 of Set 9 | kanel
# Processing Record 46 of Set 9 | balkanabat
# Processing Record 47 of Set 9 | samarai
# Processing Record 48 of Set 9 | lake shore
# Processing Record 49 of Set 9 | maningrida
# Processing Record 50 of Set 9 | hasaki
# Processing Record 1 of Set 10 | uribia
# Processing Record 2 of Set 10 | nancha
# Processing Record 3 of Set 10 | victoria
# Processing Record 4 of Set 10 | bartica
# Processing Record 5 of Set 10 | sangolqui
# Processing Record 6 of Set 10 | zhigansk
# Processing Record 7 of Set 10 | hobyo
# Processing Record 8 of Set 10 | kualakapuas
# Processing Record 9 of Set 10 | sarlat-la-caneda
# Processing Record 10 of Set 10 | havoysund
# Processing Record 11 of Set 10 | katangli
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | whitehorse
# Processing Record 14 of Set 10 | mayo
# Processing Record 15 of Set 10 | coahuayana
# Processing Record 16 of Set 10 | dwarka
# Processing Record 17 of Set 10 | krasnoselkup
# Processing Record 18 of Set 10 | mount gambier
# Processing Record 19 of Set 10 | severnoye
# Processing Record 20 of Set 10 | mahanoro
# Processing Record 21 of Set 10 | mongoumba
# Processing Record 22 of Set 10 | kruisfontein
# Processing Record 23 of Set 10 | tromso
# Processing Record 24 of Set 10 | sioux lookout
# Processing Record 25 of Set 10 | namibe
# Processing Record 26 of Set 10 | nabire
# Processing Record 27 of Set 10 | ambilobe
# Processing Record 28 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 29 of Set 10 | mazeikiai
# Processing Record 30 of Set 10 | cagmanaba
# Processing Record 31 of Set 10 | scotts valley
# Processing Record 32 of Set 10 | shetpe
# Processing Record 33 of Set 10 | am timan
# Processing Record 34 of Set 10 | hof
# Processing Record 35 of Set 10 | kayerkan
# Processing Record 36 of Set 10 | sakakah
# Processing Record 37 of Set 10 | khilok
# Processing Record 38 of Set 10 | srandakan
# Processing Record 39 of Set 10 | znamenskoye
# Processing Record 40 of Set 10 | moron
# Processing Record 41 of Set 10 | alice springs
# Processing Record 42 of Set 10 | ambulu
# Processing Record 43 of Set 10 | carnarvon
# Processing Record 44 of Set 10 | camana
# Processing Record 45 of Set 10 | seymchan
# Processing Record 46 of Set 10 | gamba
# Processing Record 47 of Set 10 | bukama
# Processing Record 48 of Set 10 | half moon bay
# Processing Record 49 of Set 10 | constitucion
# Processing Record 50 of Set 10 | neuquen
# Processing Record 1 of Set 11 | rocha
# Processing Record 2 of Set 11 | iquitos
# Processing Record 3 of Set 11 | yulara
# Processing Record 4 of Set 11 | koroni
# Processing Record 5 of Set 11 | paracuru
# Processing Record 6 of Set 11 | takoradi
# Processing Record 7 of Set 11 | sechura
# Processing Record 8 of Set 11 | martinsburg
# Processing Record 9 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 10 of Set 11 | carpentras
# Processing Record 11 of Set 11 | gigmoto
# Processing Record 12 of Set 11 | camalu
# Processing Record 13 of Set 11 | kattivakkam
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | zambezi
# Processing Record 16 of Set 11 | nishihara
# Processing Record 17 of Set 11 | oro valley
# Processing Record 18 of Set 11 | ust-nera
# Processing Record 19 of Set 11 | kroderen
# City not found. Skipping...
# Processing Record 20 of Set 11 | kahului
# Processing Record 21 of Set 11 | smithers
# Processing Record 22 of Set 11 | etchoropo
# Processing Record 23 of Set 11 | lira
# Processing Record 24 of Set 11 | quang ngai
# Processing Record 25 of Set 11 | kloulklubed
# Processing Record 26 of Set 11 | berdigestyakh
# Processing Record 27 of Set 11 | batagay
# Processing Record 28 of Set 11 | tokmak
# Processing Record 29 of Set 11 | guerrero negro
# Processing Record 30 of Set 11 | wichita
# Processing Record 31 of Set 11 | bengbu
# Processing Record 32 of Set 11 | bahia de caraquez
# Processing Record 33 of Set 11 | mama
# Processing Record 34 of Set 11 | houma
# Processing Record 35 of Set 11 | mutata
# Processing Record 36 of Set 11 | axim
# Processing Record 37 of Set 11 | noumea
# Processing Record 38 of Set 11 | ibb
# Processing Record 39 of Set 11 | xihe
# Processing Record 40 of Set 11 | mogadishu
# Processing Record 41 of Set 11 | san rafael
# Processing Record 42 of Set 11 | najran
# Processing Record 43 of Set 11 | gibara
# Processing Record 44 of Set 11 | kouroussa
# Processing Record 45 of Set 11 | wajir
# Processing Record 46 of Set 11 | talcahuano
# Processing Record 47 of Set 11 | kulaman
# Processing Record 48 of Set 11 | margate
# Processing Record 49 of Set 11 | eyl
# Processing Record 50 of Set 11 | vilhena
# Processing Record 1 of Set 12 | davila
# Processing Record 2 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 12 | miramar
# Processing Record 4 of Set 12 | nouakchott
# Processing Record 5 of Set 12 | george town
# Processing Record 6 of Set 12 | ahipara
# Processing Record 7 of Set 12 | sao felix do xingu
# Processing Record 8 of Set 12 | turayf
# Processing Record 9 of Set 12 | west wendover
# Processing Record 10 of Set 12 | boende
# Processing Record 11 of Set 12 | kindu
# Processing Record 12 of Set 12 | neiafu
# Processing Record 13 of Set 12 | sorong
# Processing Record 14 of Set 12 | yumen
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | vredendal
# Processing Record 17 of Set 12 | ures
# Processing Record 18 of Set 12 | itarema
# Processing Record 19 of Set 12 | floro
# Processing Record 20 of Set 12 | tyukhtet
# Processing Record 21 of Set 12 | bradulet
# Processing Record 22 of Set 12 | outram
# Processing Record 23 of Set 12 | batemans bay
# Processing Record 24 of Set 12 | prado
# Processing Record 25 of Set 12 | kerema
# Processing Record 26 of Set 12 | saint-joseph
# Processing Record 27 of Set 12 | alofi
# Processing Record 28 of Set 12 | orlik
# Processing Record 29 of Set 12 | shaoyang
# Processing Record 30 of Set 12 | basoko
# Processing Record 31 of Set 12 | plymouth
# Processing Record 32 of Set 12 | guarapari
# Processing Record 33 of Set 12 | port hardy
# Processing Record 34 of Set 12 | tchaourou
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | birjand
# Processing Record 37 of Set 12 | hambantota
# Processing Record 38 of Set 12 | okha
# Processing Record 39 of Set 12 | cabo san lucas
# Processing Record 40 of Set 12 | halifax
# Processing Record 41 of Set 12 | panzhihua
# Processing Record 42 of Set 12 | homburg
# Processing Record 43 of Set 12 | huai yot
# Processing Record 44 of Set 12 | san patricio
# Processing Record 45 of Set 12 | dryden
# Processing Record 46 of Set 12 | lewiston
# Processing Record 47 of Set 12 | cockburn town
# Processing Record 48 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 12 | alta floresta
# Processing Record 50 of Set 12 | redcar
# Processing Record 1 of Set 13 | barbatesti
# Processing Record 2 of Set 13 | aklavik
# Processing Record 3 of Set 13 | beloha
# Processing Record 4 of Set 13 | plavsk
# Processing Record 5 of Set 13 | makarov
# Processing Record 6 of Set 13 | irtyshskiy
# Processing Record 7 of Set 13 | nuuk
# Processing Record 8 of Set 13 | linxi
# Processing Record 9 of Set 13 | teya
# Processing Record 10 of Set 13 | cookeville
# Processing Record 11 of Set 13 | kokopo
# Processing Record 12 of Set 13 | la ronge
# Processing Record 13 of Set 13 | fez
# Processing Record 14 of Set 13 | valparaiso
# Processing Record 15 of Set 13 | bay roberts
# Processing Record 16 of Set 13 | mangalam
# Processing Record 17 of Set 13 | grindavik
# Processing Record 18 of Set 13 | semirom
# Processing Record 19 of Set 13 | atikokan
# Processing Record 20 of Set 13 | viedma
# Processing Record 21 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 13 | cervo
# Processing Record 23 of Set 13 | sumbe
# Processing Record 24 of Set 13 | kota belud
# Processing Record 25 of Set 13 | lesnoye
# Processing Record 26 of Set 13 | cootamundra
# Processing Record 27 of Set 13 | sibolga
# Processing Record 28 of Set 13 | sao joao da barra
# Processing Record 29 of Set 13 | praia da vitoria
# Processing Record 30 of Set 13 | mana
# Processing Record 31 of Set 13 | adre
# Processing Record 32 of Set 13 | tutoia
# Processing Record 33 of Set 13 | huarmey
# Processing Record 34 of Set 13 | awjilah
# Processing Record 35 of Set 13 | sobolevo
# Processing Record 36 of Set 13 | kachiry
# Processing Record 37 of Set 13 | plettenberg bay
# Processing Record 38 of Set 13 | los llanos de aridane
# Processing Record 39 of Set 13 | tual
# Processing Record 40 of Set 13 | wagga wagga
# Processing Record 41 of Set 13 | sibiti
# Processing Record 42 of Set 13 | koslan
# Processing Record 43 of Set 13 | barranca
# Processing Record 44 of Set 13 | pasighat
# Processing Record 45 of Set 13 | baft
# Processing Record 46 of Set 13 | sa kaeo
# Processing Record 47 of Set 13 | trujillo
# Processing Record 48 of Set 13 | hit
# Processing Record 49 of Set 13 | sakaiminato
# Processing Record 50 of Set 13 | sur
# Processing Record 1 of Set 14 | siderno
# Processing Record 2 of Set 14 | santa fe
# Processing Record 3 of Set 14 | bozhou
# Processing Record 4 of Set 14 | severobaykalsk
# Processing Record 5 of Set 14 | jiayuguan
# Processing Record 6 of Set 14 | eldoret
# Processing Record 7 of Set 14 | nizwa
# Processing Record 8 of Set 14 | kaseda
# Processing Record 9 of Set 14 | turukhansk
# Processing Record 10 of Set 14 | rio grande
# Processing Record 11 of Set 14 | tifton
# Processing Record 12 of Set 14 | mandalgovi
# Processing Record 13 of Set 14 | de-kastri
# Processing Record 14 of Set 14 | manta
# Processing Record 15 of Set 14 | tumalaytay
# Processing Record 16 of Set 14 | juuru
# Processing Record 17 of Set 14 | coihaique
# Processing Record 18 of Set 14 | andros town
# Processing Record 19 of Set 14 | inongo
# Processing Record 20 of Set 14 | chigorodo
# Processing Record 21 of Set 14 | jardim
# Processing Record 22 of Set 14 | muroto
# Processing Record 23 of Set 14 | troitskoye
# Processing Record 24 of Set 14 | zyryanovskiy
# City not found. Skipping...
# Processing Record 25 of Set 14 | mecca
# Processing Record 26 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 27 of Set 14 | normandin
# Processing Record 28 of Set 14 | sambava
# Processing Record 29 of Set 14 | sabang
# Processing Record 30 of Set 14 | puerto gaitan
# Processing Record 31 of Set 14 | bani
# Processing Record 32 of Set 14 | papara
# Processing Record 33 of Set 14 | merauke
# Processing Record 34 of Set 14 | nantong
# Processing Record 35 of Set 14 | kantunilkin
# Processing Record 36 of Set 14 | filadelfia
# Processing Record 37 of Set 14 | xaltianguis
# Processing Record 38 of Set 14 | joutseno
# Processing Record 39 of Set 14 | pincher creek
# Processing Record 40 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 14 | sitio novo do tocantins
# Processing Record 42 of Set 14 | worthington
# Processing Record 43 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 44 of Set 14 | gimbi
# Processing Record 45 of Set 14 | lewistown
# Processing Record 46 of Set 14 | tautira
# Processing Record 47 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 14 | kissidougou
# Processing Record 49 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 14 | fatsa
# Processing Record 1 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 15 | beisfjord
# Processing Record 3 of Set 15 | yopal
# Processing Record 4 of Set 15 | nerchinskiy zavod
# Processing Record 5 of Set 15 | pskov
# Processing Record 6 of Set 15 | batesville
# Processing Record 7 of Set 15 | verkh-usugli
# Processing Record 8 of Set 15 | changde
# Processing Record 9 of Set 15 | joshimath
# Processing Record 10 of Set 15 | husavik
# Processing Record 11 of Set 15 | puerto escondido
# Processing Record 12 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 15 | eenhana
# Processing Record 14 of Set 15 | tanhacu
# Processing Record 15 of Set 15 | gobabis
# Processing Record 16 of Set 15 | selfoss
# Processing Record 17 of Set 15 | athabasca
# Processing Record 18 of Set 15 | staryy nadym
# Processing Record 19 of Set 15 | taiping
# Processing Record 20 of Set 15 | vanino
# Processing Record 21 of Set 15 | roald
# Processing Record 22 of Set 15 | polovinnoye
# Processing Record 23 of Set 15 | podor
# Processing Record 24 of Set 15 | maues
# Processing Record 25 of Set 15 | gat
# Processing Record 26 of Set 15 | yefimovskiy
# City not found. Skipping...
# Processing Record 27 of Set 15 | sandwick
# Processing Record 28 of Set 15 | namwala
# Processing Record 29 of Set 15 | teluk intan
# Processing Record 30 of Set 15 | aksay
# Processing Record 31 of Set 15 | las matas de farfan
# Processing Record 32 of Set 15 | pontes e lacerda
# Processing Record 33 of Set 15 | ust-shonosha
# Processing Record 34 of Set 15 | taoudenni
# Processing Record 35 of Set 15 | chadan
# Processing Record 36 of Set 15 | zhuhai
# Processing Record 37 of Set 15 | boyolangu
# Processing Record 38 of Set 15 | sosnovka
# Processing Record 39 of Set 15 | hokitika
# Processing Record 40 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 15 | mayskiy
# Processing Record 43 of Set 15 | el paujil
# Processing Record 44 of Set 15 | bucak
# Processing Record 45 of Set 15 | santa cruz del sur
# Processing Record 46 of Set 15 | eureka
# Processing Record 47 of Set 15 | nova olimpia
# Processing Record 48 of Set 15 | waingapu
# Processing Record 49 of Set 15 | wattegama
# Processing Record 50 of Set 15 | oranjestad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
