# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(10)
# Out:
#    City_ID         City Country  Max Temp Current Description    Lat     Lng  \
# 0        4      Rikitea      PF     75.34          light rain -23.12 -134.97
# 1        5    Kavaratti      IN     82.42       broken clouds  10.57   72.64
# 2        6  Miandrivazo      MG     78.82           clear sky -19.52   45.47
# 3       13       Hirara      JP     76.62     overcast clouds  24.80  125.28
# 4       15       Castro      BR     72.09     overcast clouds -24.79  -50.01
# 5       18  Guadalajara      MX     88.00    scattered clouds  20.67 -103.33
# 6       22     Souillac      MU     73.40    scattered clouds -20.52   57.52
# 7       23       Rawson      AR     71.13     overcast clouds -43.30  -65.10
# 8       26      Mangrol      IN     82.18           clear sky  21.12   70.12
# 9       27    Hithadhoo      MV     83.16          few clouds  -0.60   73.08
#
#                        Hotel Name
# 0                  Pension Maro'i
# 1   Hotels in Lakshadweep Islands
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# test
vacation_start = vacation_df.loc[3]
vacation_start
# Out:
# City_ID                                            13
# City                                           Hirara
# Country                                            JP
# Max Temp                                        76.62
# Current Description                   overcast clouds
# Lat                                              24.8
# Lng                                            125.28
# Hotel Name             Hotel Atoll Emerald Miyakojima
# Name: 3, dtype: object

# %%
# test
filter_US = vacation_df["Country"] == "US"
vacation_df.loc[filter_US]
#filter_US.sum()
# Out:
#      City_ID           City Country  Max Temp Current Description    Lat  \
# 14        47          Kapaa      US     84.20    scattered clouds  22.08
# 18        64        Kahului      US     87.80          few clouds  20.89
# 21        68           Hilo      US     78.01     overcast clouds  19.73
# 51       135       Marshall      US     75.00       broken clouds  34.38
# 75       227        Fortuna      US     72.00           clear sky  40.60
# 99       287         Eureka      US     73.00           clear sky  40.80
# 108      303         Laguna      US     72.00           clear sky  38.42
# 134      368  Half Moon Bay      US     71.60           clear sky  37.46
# 136      371         Ensley      US     86.00           clear sky  30.52
# 139      381       Pacifica      US     70.00           clear sky  37.61
# 150      410        Russell      US     82.40       broken clouds  32.35
# 157      424        Labelle      US     87.01     overcast clouds  26.76
# ...

# %%
# test
vacation_df.head().to_numpy()[0][:]
# Out:
# array([4, 'Rikitea', 'PF', 75.34, 'light rain', -23.12, -134.97,
#        "Pension Maro'i"], dtype=object)

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[134].to_frame().T
vacation_end = vacation_df.loc[134].to_frame().T
vacation_stop1 = vacation_df.loc[139].to_frame().T
vacation_stop2 = vacation_df.loc[221].to_frame().T
vacation_stop3 = vacation_df.loc[204].to_frame().T

# %%
# test
columns = ['City', 'Country', 'Lat']
start = vacation_df[['Lat', 'Lng']].to_numpy()[134]
vacation_df[columns].loc[134]
start
# vacation_df
# Out:
# array([  37.46, -122.43])

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_df[['Lat', 'Lng']].to_numpy()[134]
end = vacation_df[['Lat', 'Lng']].to_numpy()[134]
stop1 = vacation_df[['Lat', 'Lng']].to_numpy()[139]
stop2 = vacation_df[['Lat', 'Lng']].to_numpy()[221]
stop3 = vacation_df[['Lat', 'Lng']].to_numpy()[204]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
vacation_itenerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(vacation_itenerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1,
                          vacation_stop2, vacation_stop3], ignore_index=True)
itinerary_df
# Out:
#   City_ID           City Country Max Temp Current Description    Lat     Lng  \
# 0     368  Half Moon Bay      US     71.6           clear sky  37.46 -122.43
# 1     368  Half Moon Bay      US     71.6           clear sky  37.46 -122.43
# 2     381       Pacifica      US       70           clear sky  37.61 -122.49
# 3     581  Pacific Grove      US     71.6           clear sky  36.62 -121.92
# 4     547      San Ramon      US    71.01           clear sky  37.78 -121.98
#
#                                           Hotel Name
# 0                    The Ritz-Carlton, Half Moon Bay
# 1                    The Ritz-Carlton, Half Moon Bay
# 2  Pacifica Lighthouse, Trademark Collection by W...
# 3                                   Lovers Point Inn
# 4                                 San Ramon Marriott

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
